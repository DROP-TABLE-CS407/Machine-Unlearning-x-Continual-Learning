# %% [markdown]
# # Gradient Episodic Memory for Continual Learning
#
# We adapt the GEM algorithm to train the ResNet18 model on the CIFAR-10 Dataset. The GEM algorithm is a continual learning algorithm that prevents catastrophic forgetting by constraining the gradient updates on the new task to be orthogonal to the gradients of the previous tasks. The algorithm is implemented in PyTorch.

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from torchvision import transforms
import time
from cifar import load_cifar10_data, split_into_classes, get_class_indexes 
from torch.utils.data import DataLoader
import random
import os
import sys
sys.path.append(os.path.abspath("."))  # Adds the current directory
# from GEM.gem import *
from GEM.args import *
from torch.nn.functional import relu, avg_pool2d
import torch.nn as nn
import quadprog

AGEM = True
PRETRAIN = 4 # number of initial classes to pretrain on
# Globals 
DATASET_PATH = 'cifar-10-batches-py' 
CLASSES = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
SHUFFLEDCLASSES = CLASSES.copy()

CUT_OFF_ACCURACY = 0.80

# %%
## Scraped code fundamental for GEM this is the code required to create a resnet18 model from scratch 
def conv3x3(in_planes, out_planes, stride=1):
    return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride,
                     padding=1, bias=False)

class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = conv3x3(in_planes, planes, stride)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = conv3x3(planes, planes)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1,
                          stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = relu(out)
        return out

class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes, nf):
        super(ResNet, self).__init__()
        self.in_planes = nf
        self.conv1 = conv3x3(3, nf * 1)
        self.bn1 = nn.BatchNorm2d(nf * 1)
        self.layer1 = self._make_layer(block, nf * 1, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, nf * 2, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, nf * 4, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, nf * 8, num_blocks[3], stride=2)
        self.linear = nn.Linear(nf * 8 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        bsz = x.size(0)
        out = relu(self.bn1(self.conv1(x.view(bsz, 3, 32, 32))))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18(nclasses, nf=20):
    return ResNet(BasicBlock, [2, 2, 2, 2], nclasses, nf)

# %%
### Now lets make the GEM model --  we will scrape this from the GEM code
def compute_offsets(task, nc_per_task, is_cifar):
    """
        Compute offsets for cifar to determine which
        outputs to select for a given task.
    """
    val1 = max(PRETRAIN - nc_per_task, 0)
    val2 = max(PRETRAIN - nc_per_task, 0)
    if task == 0:
        val1 = 0
        val2 = max(PRETRAIN - nc_per_task, 0)
    offset1 = task * nc_per_task + val1
    offset2 = (task + 1) * nc_per_task + val2    
    return offset1, offset2


def store_grad(pp, grads, grad_dims, tid):
    """
        This stores parameter gradients of past tasks.
        pp: parameters
        grads: gradients
        grad_dims: list with number of parameters per layers
        tid: task id
    """
    # store the gradients
    grads[:, tid].fill_(0.0)
    cnt = 0
    for param in pp():
        if param.grad is not None:
            beg = 0 if cnt == 0 else sum(grad_dims[:cnt])
            en = sum(grad_dims[:cnt + 1])
            grads[beg: en, tid].copy_(param.grad.data.view(-1))
        cnt += 1


def overwrite_grad(pp, newgrad, grad_dims):
    """
        This is used to overwrite the gradients with a new gradient
        vector, whenever violations occur.
        pp: parameters
        newgrad: corrected gradient
        grad_dims: list storing number of parameters at each layer
    """
    cnt = 0
    for param in pp():
        if param.grad is not None:
            beg = 0 if cnt == 0 else sum(grad_dims[:cnt])
            en = sum(grad_dims[:cnt + 1])
            this_grad = newgrad[beg: en].contiguous().view(
                param.grad.data.size())
            param.grad.data.copy_(this_grad)
        cnt += 1


def project2cone2(gradient, memories, margin=0.5, eps=1e-3):
    """
        Solves the GEM dual QP described in the paper given a proposed
        gradient "gradient", and a memory of task gradients "memories".
        Overwrites "gradient" with the final projected update.

        input:  gradient, p-vector
        input:  memories, (t * p)-vector
        output: x, p-vector
    """
    memories_np = memories.cpu().t().double().numpy()
    gradient_np = gradient.cpu().contiguous().view(-1).double().numpy()
    t = memories_np.shape[0]
    P = np.dot(memories_np, memories_np.transpose())
    P = 0.5 * (P + P.transpose()) + np.eye(t) * eps
    q = np.dot(memories_np, gradient_np) * -1
    G = np.eye(t)
    h = np.zeros(t) + margin
    v = quadprog.solve_qp(P, q, G, h)[0]
    x = np.dot(v, memories_np) + gradient_np
    gradient.copy_(torch.Tensor(x).view(-1, 1))

def agemprojection(gradient, gradient_memory, margin=0.5, eps=1e-3):
    """
    Projection of gradients for A-GEM with the memory approach
    Use averaged gradient memory for projection
    
    input:  gradient, g-reference
    output: gradient, g-projected
    """
    """
    # print(gradient.shape)
    gref  = gradient_memory.cpu().t().double().numpy().mean(axis=0)
    # print(gref.shape)
    g = gradient.cpu().contiguous().view(-1).double().numpy()
    # print(g.shape)
    g_transpose = g.transpose()
    # print(g_transpose.shape)
    gref_transpose = gref.transpose()
    # print(gref_transpose.shape)
    # check g_transpose and gref are of the same shape
    
    dot_prod = np.dot(g_transpose, gref.squeeze())
    # print(dot_prod.shape)
    # dot product constraint has already been checked

    # projection
    dot_prod = dot_prod / np.dot(gref, gref_transpose)
    # print(dot_prod.shape)
    g = g - np.dot(dot_prod, gref)
    # print(g.shape)
    gradient.copy_(torch.Tensor(g))
    """
    gref = gradient_memory.t().double().mean(axis=0).cuda()
    g = gradient.contiguous().view(-1).double().cuda()
    g_transpose = g.view(1, -1)
    gref_transpose = gref.view(1, -1)
    dot_prod = torch.dot(g_transpose.squeeze(), gref.squeeze())
    dot_prod = dot_prod / torch.dot(gref_transpose.squeeze(), gref.squeeze())
    # add epsilon to prevent numerical instability  
    epsvector = torch.Tensor([eps]).cuda()
    
    x = gref*0.5 - (g.squeeze() * dot_prod)
    gradient.copy_(torch.Tensor(x).view(-1, 1))
    
def replay(gradient, gradient_memory):
    """
    Adds the gradients of the current task to the memory 
    
    input:  gradient, g-reference
    output: gradient, g-projected
    """
    g = gradient_memory.t().double().mean(axis=0).cuda()
    gref = gradient.contiguous().view(-1).double().cuda()
    # simply add the gradients
    g = g + gref
    gradient.copy_(torch.Tensor(g).view(-1, 1))
    
def naiveretraining(gradient):
    """
    Naive retraining of the model on the current task
    
    input:  gradient, g-reference
    output: gradient, g-projected
    """
    g = gradient.t().double().mean(axis=0).cuda()
    gradient.copy_(torch.Tensor(g).view(-1, 1))
    

class Net(nn.Module):
    def __init__(self,
                 n_inputs,
                 n_outputs,
                 n_tasks,
                 args):
        super(Net, self).__init__()
        nl, nh = args.n_layers, args.n_hiddens
        self.margin = args.memory_strength
        self.net = ResNet18(n_outputs)
     

        self.ce = nn.CrossEntropyLoss()
        self.n_outputs = n_outputs

        self.opt = torch.optim.SGD(self.parameters(), args.lr)

        self.n_memories = args.n_memories
        self.gpu = args.cuda


        """
        Allocate episodic memory
        n_tasks: number of tasks
        n_memories: number of memories per task
        n_inputs: number of input features
        """

        # allocate episodic memory
        self.memory_data = torch.FloatTensor(
            n_tasks, self.n_memories, n_inputs)
        self.memory_labs = torch.LongTensor(n_tasks, self.n_memories)
        if args.cuda:
            self.memory_data = self.memory_data.cuda()
            self.memory_labs = self.memory_labs.cuda()

        # allocate temporary synaptic memory
        """ This is the memory that stores the gradients of the parameters of the network
            FOR each task. This is used to check for violations of the GEM constraint
            Assume:

            The model has 3 parameters with sizes 100, 200, and 300 elements respectively.
            n_tasks = 5 (number of tasks).
            The allocated tensors would have the following shapes:

            self.grad_dims: [100, 200, 300]
            self.grads: Shape [600, 5] (600 is the sum of 100, 200, and 300).
        """
        self.grad_dims = []
        for param in self.parameters():
            self.grad_dims.append(param.data.numel())
        self.grads = torch.Tensor(sum(self.grad_dims), n_tasks)
        if args.cuda:
            self.grads = self.grads.cuda()

        # allocate counters
        self.observed_tasks = []
        self.old_task = -1
        self.mem_cnt = 0
        minus = 0
        if PRETRAIN > 0:
            minus = 1
        else: 
            minus = 0
        self.nc_per_task = int((n_outputs - PRETRAIN) / (n_tasks - minus))

    def forward(self, x, t):
        output = self.net(x)
        if t == -1:
            return output
        # make sure we predict classes within the current task
        val1 = 0
        val2 = 0
        if t != 0:
            val1 = max(PRETRAIN - self.nc_per_task, 0)
            val2 = val1
        else:
            val1 = 0
            val2 = max(PRETRAIN - self.nc_per_task, 0)                                                 
        offset1 = int(t * self.nc_per_task + val1) #t = 0 0, 5 -----t = 1 5 , 6 ## t = 0 0 ,5 --- t =1 5, 7
        offset2 = int((t + 1) * self.nc_per_task + val2) 
        if offset1 > 0:
            output[:, :offset1].data.fill_(-10e10)
        if offset2 < self.n_outputs:
            output[:, offset2:self.n_outputs].data.fill_(-10e10)
        return output

    def observe(self, algorithm, x, t, y):
        # update memory
        if t != self.old_task:
            self.observed_tasks.append(t)
            self.old_task = t
            
        val = 0
        if t == 0:
            val = max(PRETRAIN,1)
        else:
            val = 1
        # Update ring buffer storing examples from current task
        bsz = y.data.size(0)
        if (algorithm == 'NAIVE'):
            self.zero_grad()
            loss = self.ce(self.forward(x, t), y)
            loss.backward()
            self.opt.step()
            return
        endcnt = min(self.mem_cnt + bsz, self.n_memories) #256
        effbsz = endcnt - self.mem_cnt # 256
        self.memory_data[t, self.mem_cnt: endcnt].copy_(
            x.data[: effbsz])
        if bsz == 1:
            self.memory_labs[t, self.mem_cnt] = y.data[0]
        else:
            self.memory_labs[t, self.mem_cnt: endcnt].copy_(
                y.data[: effbsz])
        self.mem_cnt += effbsz
        if self.mem_cnt == self.n_memories:
            self.mem_cnt = 0

        # compute gradient on previous tasks
        # if PRETRAIN == 0:
        #     val = 1
        # else:
        #     val = 0
        if len(self.observed_tasks) > 1: ### CHANGED FROM 1 to 0 SINCE WE PRETRAIN ON FST 5 CLASSES 
            for tt in range(len(self.observed_tasks) -1): ### CHANGED FROM -1 to -0 SINCE WE PRETRAIN ON FST 5 CLASSES 
                self.zero_grad()
                # fwd/bwd on the examples in the memory
                past_task = self.observed_tasks[tt]
                
                offset1, offset2 = compute_offsets(past_task, self.nc_per_task,
                                                   self.is_cifar)
                ptloss = self.ce(
                    self.forward(
                        self.memory_data[past_task],
                        past_task)[:, offset1: offset2],
                    self.memory_labs[past_task] - offset1)
                ptloss.backward()
                store_grad(self.parameters, self.grads, self.grad_dims,
                           past_task)

        # now compute the grad on the current minibatch
        self.zero_grad()

        offset1, offset2 = compute_offsets(t, self.nc_per_task, self.is_cifar) 
        loss = self.ce(self.forward(x, t)[:, offset1: offset2], y - offset1)
        loss.backward()
        #if algorithm == 'NAIVE':
        #    naiveretraining(self.grads[:, t].unsqueeze(1))
        #    overwrite_grad(self.parameters, self.grads[:, t],
        #                self.grad_dims)
        #    self.opt.step()
        #    return

        # check if gradient violates constraints
        if len(self.observed_tasks) > 1: ### CHANGED FROM 1 to 0 SINCE WE PRETRAIN ON FST 5 CLASSES 
            if algorithm == 'AGEM':
                store_grad(self.parameters, self.grads, self.grad_dims, t)
                indx = torch.cuda.LongTensor(self.observed_tasks[:-1]) if self.gpu \
                    else torch.LongTensor(self.observed_tasks[:-1])
                dotp = torch.mm(self.grads[:, t].unsqueeze(0),
                                self.grads.index_select(1, indx))
                if (dotp < 0).sum() != 0:
                    agemprojection(self.grads[:, t].unsqueeze(1), self.grads.index_select(1, indx), self.margin)
                    # copy gradients back
                    overwrite_grad(self.parameters, self.grads[:, t],
                                self.grad_dims)
            # copy gradient
            elif algorithm == 'GEM':
                store_grad(self.parameters, self.grads, self.grad_dims, t)
                indx = torch.cuda.LongTensor(self.observed_tasks[:-1]) if self.gpu \
                    else torch.LongTensor(self.observed_tasks[:-1])
                dotp = torch.mm(self.grads[:, t].unsqueeze(0),
                                self.grads.index_select(1, indx))
                if (dotp < 0).sum() != 0:
                    project2cone2(self.grads[:, t].unsqueeze(1),
                                self.grads.index_select(1, indx), self.margin)
                    # copy gradients back
                    overwrite_grad(self.parameters, self.grads[:, t],
                                self.grad_dims)
            elif algorithm == 'REPLAY':
                store_grad(self.parameters, self.grads, self.grad_dims, t)
                indx = torch.cuda.LongTensor(self.observed_tasks[:-1]) if self.gpu \
                    else torch.LongTensor(self.observed_tasks[:-1])
                replay(self.grads[:, t].unsqueeze(1), self.grads.index_select(1, indx))
                # copy gradients back
                overwrite_grad(self.parameters, self.grads[:, t],
                            self.grad_dims)
        self.opt.step()

# %%
# define main function to run on the cifar dataset
N_TASKS = 4 #[2 tasks [airplane, automobile, etc], [dog , frog, etc]]
SIZE_OF_TASKS = 2
N_OUTPUTS = 10
N_INPUTS = 32 * 32 * 3
def run_cifar(algorithm, args, n_inputs=N_INPUTS, n_outputs=N_OUTPUTS, n_tasks=N_TASKS, size_of_task=SIZE_OF_TASKS, newclasses = SHUFFLEDCLASSES):
    # Set up the model
    model = Net(n_inputs, n_outputs, n_tasks, args)
    if args.cuda:
        model.cuda()
    model.is_cifar = True
    test_bs = 1000
    
    test_accuracies = []

    # Load data
    train_data, train_labels, test_data, test_labels = load_cifar10_data(DATASET_PATH)
    ## NEWCLASSES = suffled CLASSES
    NEWCLASSES = newclasses
    print("new ordering of classes: ", NEWCLASSES)
    oldClasstoNewClass = {}
    for i in range(len(CLASSES)):
        oldClasstoNewClass[i] = NEWCLASSES.index(CLASSES[i])
    for i in range(len(train_labels)):
        train_labels[i] = oldClasstoNewClass[train_labels[i]]
    for i in range(len(test_labels)):
        test_labels[i] = oldClasstoNewClass[test_labels[i]]

    pretrain_classses = NEWCLASSES[:PRETRAIN]
    pretrain_data, pretrain_labels = split_into_classes(train_data, train_labels, pretrain_classses, NEWCLASSES)
    pretest_data, pretest_labels = split_into_classes(test_data, test_labels, pretrain_classses, NEWCLASSES)
    tasks = []
    tests = []
    if PRETRAIN > 0:
        tasks = [[pretrain_data, pretrain_labels]]
        tests = [pretest_data, pretest_labels]
    else:

        tasks = []
        tests = []
    for i  in range(n_tasks):
        if i == 0 and PRETRAIN > 0: ## as task 1 we already grab from 
            continue
        elif PRETRAIN > 0:
            task_data, task_labels = split_into_classes(train_data, train_labels, NEWCLASSES[PRETRAIN + size_of_task * (i-1) : PRETRAIN + size_of_task * (i)], NEWCLASSES)
            tasks.append([task_data, task_labels])
            partition_test_data, partition_test_labels = split_into_classes(test_data, test_labels, NEWCLASSES[PRETRAIN + size_of_task * (i-1) : PRETRAIN + size_of_task * (i)], NEWCLASSES)
            tests.append(partition_test_data)
            tests.append(partition_test_labels)
        else:
            task_data, task_labels = split_into_classes(train_data, train_labels, NEWCLASSES[size_of_task * i : size_of_task * (i + 1)] , NEWCLASSES)
            tasks.append([task_data, task_labels])
            partition_test_data, partition_test_labels = split_into_classes(test_data, test_labels, NEWCLASSES[size_of_task * i : size_of_task * (i + 1)] , NEWCLASSES)
            tests.append(partition_test_data)
            tests.append(partition_test_labels)
        
    # task1data, task1labels = split_into_classes(train_data, train_labels, ['airplane', 'automobile', 'bird', 'cat', 'deer']) ## pre train on this 
    # task2data, task2labels = split_into_classes(train_data, train_labels, ['dog', 'frog', 'horse', 'ship', 'truck']) ## split this guy up into 5 tasks 
    # # tasks = [[task1data, task1labels], [task2data,task2labels]]
    # test_data_per_class_1, test_labels_per_class_1 = split_into_classes(test_data, test_labels, ['airplane', 'automobile', 'bird', 'cat', 'deer'])
    # test_data_per_class_2, test_labels_per_class_2 = split_into_classes(test_data, test_labels, ['dog', 'frog', 'horse', 'ship', 'truck'])

    # Train the model
    for task in range(n_tasks):
        print("Training task: ", task  + 1)
        
        x = torch.Tensor(tasks[task][0].reshape(-1, 32*32*3)).float()
        y = torch.Tensor(tasks[task][1]).long()
        
        if args.cuda:
            x, y = x.cuda(), y.cuda()
    
        for epoch in range(args.n_epochs):
            for j in range(0, len(tasks[task][0]), args.batch_size):
                current_data = x[j: j + args.batch_size]
                current_labels = y[j: j + args.batch_size]
                model.train()
                model.observe(algorithm, current_data, task, current_labels)
            print("Epoch: ", epoch)
            
            #test the model after each epoch
            correct = 0
            total = len(tasks[task][0])
            for j in range(0,len(tasks[task][0]), test_bs):
                current_data = x[j: j + test_bs]
                current_labels = y[j: j + test_bs]
                output = model.forward(current_data, task)
                pred = output.data.max(1)[1]
                correct += (pred == current_labels).sum().item()
            print("Accuracy: ", correct / total)
            if correct / total > CUT_OFF_ACCURACY:
                break
            #   output loss only


    # Test the model after training
        for i in range(0, len(tests), 2):
            correct = 0
            total = len(tests[i])     

            # Test the model
            print("Testing task: " , i // 2 + 1)
            
            x = torch.Tensor(tests[i].reshape(-1, 32*32*3)).float()
            y = torch.Tensor(tests[i+1]).long()
            if args.cuda:
                x, y = x.cuda(), y.cuda()
            for j in range(0,len(tests[i]), test_bs):
                current_data = x[j: j + test_bs]
                current_labels = y[j: j + test_bs]
                output = model.forward(current_data, i // 2)
                pred = output.data.max(1)[1]
                correct += (pred == current_labels).sum().item()
            print("Accuracy: ", correct / total)
            test_accuracies.append(correct / total)
        
    return model, test_accuracies

# %%
def plot_task_accuracies(test_accuracies, num_tasks):
    for t in range(num_tasks):
        # Calculate the indices for the current set of accuracies
        start_idx = t * num_tasks
        end_idx = start_idx + num_tasks
        # Extract accuracies for all tasks after training task t+1
        accuracies = test_accuracies[start_idx:end_idx]
        # Create labels for the tasks
        task_labels = [f'Task {i+1}' for i in range(num_tasks)]
        # Plot the accuracies
        plt.bar(task_labels, [acc * 100 for acc in accuracies])

        # Calculate the y-value for the horizontal line
        y_value = 100 / SIZE_OF_TASKS  # or use SIZE_OF_TASKS if it's defined separately

        # Add horizontal line across the bar chart
        plt.axhline(y=y_value, color='red', linestyle='--', label=f'y = {y_value:.2f}')
        
        plt.title(f'Test Set Accuracy for All Tasks (Post Task {t+1} Training)')
        plt.ylabel('Accuracy (%)')
        plt.xlabel('Tasks')
        plt.legend()
        plt.show()

# %%
max_runs = 100
test_accuracies_AGEM_all = []
test_accuracies_GEM_all = []
test_accuracies_REPLAY_all = []
test_accuracies_NAIVE_all = []

for i in range(max_runs):
    print(f"Run {i+1}")
    random.shuffle(SHUFFLEDCLASSES)

    model, test_accuracies_AGEM = run_cifar('AGEM', Args())
    print(test_accuracies_AGEM)
    test_accuracies_AGEM_all.append(test_accuracies_AGEM)

    model, test_accuracies_GEM = run_cifar('GEM', Args())
    print(test_accuracies_GEM)
    test_accuracies_GEM_all.append(test_accuracies_GEM)
    
    model, test_accuracies_REPLAY = run_cifar('REPLAY', Args())
    print(test_accuracies_REPLAY)
    test_accuracies_REPLAY_all.append(test_accuracies_REPLAY)
    
    model, test_accuracies_NAIVE = run_cifar('NAIVE', Args())
    print(test_accuracies_NAIVE)
    test_accuracies_NAIVE_all.append(test_accuracies_NAIVE)
    
average_AGEM_accuracies = np.mean(test_accuracies_AGEM_all, axis=0)
average_GEM_accuracies = np.mean(test_accuracies_GEM_all, axis=0)
average_REPLAY_accuracies = np.mean(test_accuracies_REPLAY_all, axis=0)
average_NAIVE_accuracies = np.mean(test_accuracies_NAIVE_all, axis=0)

task_1_accuracies_AGEM = []
task_1_accuracies_GEM = []
task_1_accuracies_REPLAY = []
task_1_accuracies_NAIVE = []
task_1_accuracies_AGEM.append(0.5)
task_1_accuracies_GEM.append(0.5)
task_1_accuracies_REPLAY.append(0.5)
task_1_accuracies_NAIVE.append(0.5)

for i in range(0, N_TASKS * N_TASKS, N_TASKS):
    task_1_accuracies_GEM.append(average_GEM_accuracies[i])
    task_1_accuracies_AGEM.append(average_AGEM_accuracies[i])
    task_1_accuracies_REPLAY.append(average_REPLAY_accuracies[i])
    task_1_accuracies_NAIVE.append(average_NAIVE_accuracies[i])

plt.plot(task_1_accuracies_AGEM, label='AGEM')
plt.plot(task_1_accuracies_GEM, label='GEM')
plt.plot(task_1_accuracies_REPLAY, label='REPLAY')
plt.plot(task_1_accuracies_NAIVE, label='NAIVE')
plt.title('Task 1 Test Set Accuracy Comparison')
plt.ylabel('Accuracy (%)')
plt.xlabel('Tasks')
plt.legend()
plt.show()
# Out:
# Run 1
# new ordering of classes:  ['bird', 'ship', 'horse', 'cat', 'frog', 'deer', 'airplane', 'automobile', 'dog', 'truck']
# Training task:  1
# Epoch:  0
# Accuracy:  0.598
# Epoch:  1
# Accuracy:  0.69135
# Epoch:  2
# Accuracy:  0.73035
# Epoch:  3
# Accuracy:  0.7127
# Epoch:  4
# Accuracy:  0.79845
# Epoch:  5
# Accuracy:  0.8093
# Testing task:  1
# Accuracy:  0.75725
# Testing task:  2
# Accuracy:  0.513
# Testing task:  3
# Accuracy:  0.5095
# Testing task:  4
# Accuracy:  0.5
# Training task:  2
# Epoch:  0
# Accuracy:  0.7076
# Epoch:  1
# Accuracy:  0.7865
# Epoch:  2
# Accuracy:  0.8489
# Testing task:  1
# Accuracy:  0.54075
# Testing task:  2
# Accuracy:  0.826
# Testing task:  3
# Accuracy:  0.5025
# Testing task:  4
# Accuracy:  0.5
# Training task:  3
# Epoch:  0
# Accuracy:  0.8336
# Testing task:  1
# Accuracy:  0.70375
# Testing task:  2
# Accuracy:  0.8325
# Testing task:  3
# Accuracy:  0.8275
# Testing task:  4
# Accuracy:  0.5
# Training task:  4
# Epoch:  0
# Accuracy:  0.6505
# Epoch:  1
# Accuracy:  0.5776
# Epoch:  2
# Accuracy:  0.3812
# Epoch:  3
# Accuracy:  0.713
# Epoch:  4
# Accuracy:  0.7188
# Epoch:  5
# Accuracy:  0.7653
# Epoch:  6
# Accuracy:  0.7431
# Epoch:  7
# Accuracy:  0.7449
# Epoch:  8
# Accuracy:  0.7432
# Epoch:  9
# Accuracy:  0.5
# Testing task:  1
# Accuracy:  0.34325
# Testing task:  2
# Accuracy:  0.507
# Testing task:  3
# Accuracy:  0.707
# Testing task:  4
# Accuracy:  0.5
# [0.75725, 0.513, 0.5095, 0.5, 0.54075, 0.826, 0.5025, 0.5, 0.70375, 0.8325, 0.8275, 0.5, 0.34325, 0.507, 0.707, 0.5]
# new ordering of classes:  ['bird', 'ship', 'horse', 'cat', 'frog', 'deer', 'airplane', 'automobile', 'dog', 'truck']
# Training task:  1
# Epoch:  0
# Accuracy:  0.61605
# Epoch:  1
# Accuracy:  0.7025
# Epoch:  2
# Accuracy:  0.7502
# Epoch:  3
# Accuracy:  0.7498
# Epoch:  4
# Accuracy:  0.77745
# Epoch:  5
# Accuracy:  0.8246
# Testing task:  1
# Accuracy:  0.762
# Testing task:  2
# Accuracy:  0.4055
# Testing task:  3
# Accuracy:  0.493
# Testing task:  4
# Accuracy:  0.7445
# Training task:  2
# Epoch:  0
# Accuracy:  0.735
# Epoch:  1
# Accuracy:  0.7958
# Epoch:  2
# Accuracy:  0.8763
# Testing task:  1
# Accuracy:  0.6205
# Testing task:  2
# Accuracy:  0.847
# Testing task:  3
# Accuracy:  0.4825
# Testing task:  4
# Accuracy:  0.4855
# Training task:  3
# Epoch:  0
# Accuracy:  0.8996
# Testing task:  1
# Accuracy:  0.6285
# Testing task:  2
# Accuracy:  0.764
# Testing task:  3
# Accuracy:  0.9005
# Testing task:  4
# Accuracy:  0.3565
# Training task:  4
# Epoch:  0
# Accuracy:  0.9433
# Testing task:  1
# Accuracy:  0.65
# Testing task:  2
# Accuracy:  0.724
# Testing task:  3
# Accuracy:  0.8205
# Testing task:  4
# Accuracy:  0.941
# [0.762, 0.4055, 0.493, 0.7445, 0.6205, 0.847, 0.4825, 0.4855, 0.6285, 0.764, 0.9005, 0.3565, 0.65, 0.724, 0.8205, 0.941]
# new ordering of classes:  ['bird', 'ship', 'horse', 'cat', 'frog', 'deer', 'airplane', 'automobile', 'dog', 'truck']
# Training task:  1
# Epoch:  0
# Accuracy:  0.59435
# Epoch:  1
# Accuracy:  0.6864
# Epoch:  2
# Accuracy:  0.7668
# Epoch:  3
# Accuracy:  0.78515
# Epoch:  4
# Accuracy:  0.81205
# Testing task:  1
# Accuracy:  0.75475
# Testing task:  2
# Accuracy:  0.491
# Testing task:  3
# Accuracy:  0.4995
# Testing task:  4
# Accuracy:  0.5385
# Training task:  2
# Epoch:  0
# Accuracy:  0.5
# Epoch:  1
# Accuracy:  0.5873
# Epoch:  2
# Accuracy:  0.805
# Testing task:  1
# Accuracy:  0.59925
# Testing task:  2
# Accuracy:  0.7845
# Testing task:  3
# Accuracy:  0.5125
# Testing task:  4
# Accuracy:  0.5045
# Training task:  3
# Epoch:  0
# Accuracy:  0.8846
# Testing task:  1
# Accuracy:  0.61425
# Testing task:  2
# Accuracy:  0.792
# Testing task:  3
# Accuracy:  0.874
# Testing task:  4
# Accuracy:  0.5055
# Training task:  4
# Epoch:  0
# Accuracy:  0.9301
# Testing task:  1
# Accuracy:  0.61225
# Testing task:  2
# Accuracy:  0.777
# Testing task:  3
# Accuracy:  0.8695
# Testing task:  4
# Accuracy:  0.928
# [0.75475, 0.491, 0.4995, 0.5385, 0.59925, 0.7845, 0.5125, 0.5045, 0.61425, 0.792, 0.874, 0.5055, 0.61225, 0.777, 0.8695, 0.928]
# new ordering of classes:  ['bird', 'ship', 'horse', 'cat', 'frog', 'deer', 'airplane', 'automobile', 'dog', 'truck']
# Training task:  1
# Epoch:  0
# Accuracy:  0.49625
# Epoch:  1
# Accuracy:  0.6864
# Epoch:  2
# Accuracy:  0.73225
# Epoch:  3
# Accuracy:  0.77665
# Epoch:  4
# Accuracy:  0.81505
# Testing task:  1
# Accuracy:  0.76875
# Testing task:  2
# Accuracy:  0.5
# Testing task:  3
# Accuracy:  0.4085
# Testing task:  4
# Accuracy:  0.711
# Training task:  2
# Epoch:  0
# Accuracy:  0.7926
# Epoch:  1
# Accuracy:  0.8215
# Testing task:  1
# Accuracy:  0.592
# Testing task:  2
# Accuracy:  0.8035
# Testing task:  3
# Accuracy:  0.5435
# Testing task:  4
# Accuracy:  0.5945
# Training task:  3
# Epoch:  0
# Accuracy:  0.8808
# Testing task:  1
# Accuracy:  0.62125
# Testing task:  2
# Accuracy:  0.764
# Testing task:  3
# Accuracy:  0.8875
# Testing task:  4
# Accuracy:  0.519
# Training task:  4
# Epoch:  0
# Accuracy:  0.9445
# Testing task:  1
# Accuracy:  0.5795
# Testing task:  2
# Accuracy:  0.7225
# Testing task:  3
# Accuracy:  0.856
# Testing task:  4
# Accuracy:  0.9425
# [0.76875, 0.5, 0.4085, 0.711, 0.592, 0.8035, 0.5435, 0.5945, 0.62125, 0.764, 0.8875, 0.519, 0.5795, 0.7225, 0.856, 0.9425]
# Run 2
# new ordering of classes:  ['ship', 'cat', 'frog', 'dog', 'bird', 'horse', 'deer', 'truck', 'airplane', 'automobile']
# Training task:  1
# Epoch:  0
# Accuracy:  0.57715
# Epoch:  1
# Accuracy:  0.59915
# Epoch:  2
# Accuracy:  0.68815
# Epoch:  3
# Accuracy:  0.7273
# Epoch:  4
# Accuracy:  0.7179
# Epoch:  5
# Accuracy:  0.74225
# Epoch:  6
# Accuracy:  0.73465
# Epoch:  7
# Accuracy:  0.826
# Testing task:  1
# Accuracy:  0.75375
# Testing task:  2
# Accuracy:  0.4835
# Testing task:  3
# Accuracy:  0.528
# Testing task:  4
# Accuracy:  0.5
# Training task:  2
# Epoch:  0
# Accuracy:  0.6592
# Epoch:  1
# Accuracy:  0.831
# Testing task:  1
# Accuracy:  0.58725
# Testing task:  2
# Accuracy:  0.8245
# Testing task:  3
# Accuracy:  0.7015
# Testing task:  4
# Accuracy:  0.498
# Training task:  3
# Epoch:  0
# Accuracy:  0.8255
# Testing task:  1
# Accuracy:  0.6405
# Testing task:  2
# Accuracy:  0.815
# Testing task:  3
# Accuracy:  0.8255
# Testing task:  4
# Accuracy:  0.5
# Training task:  4
# Epoch:  0
# Accuracy:  0.81
# Testing task:  1
# Accuracy:  0.65075
# Testing task:  2
# Accuracy:  0.8205
# Testing task:  3
# Accuracy:  0.874
# Testing task:  4
# Accuracy:  0.8095
# [0.75375, 0.4835, 0.528, 0.5, 0.58725, 0.8245, 0.7015, 0.498, 0.6405, 0.815, 0.8255, 0.5, 0.65075, 0.8205, 0.874, 0.8095]
# new ordering of classes:  ['ship', 'cat', 'frog', 'dog', 'bird', 'horse', 'deer', 'truck', 'airplane', 'automobile']
# Training task:  1
# Epoch:  0
# Accuracy:  0.57625
# Epoch:  1
# Accuracy:  0.6183
# Epoch:  2
# Accuracy:  0.68435
# Epoch:  3
# Accuracy:  0.73505
# Epoch:  4
# Accuracy:  0.7249
# Epoch:  5
# Accuracy:  0.77185
# Epoch:  6
# Accuracy:  0.7965
# Epoch:  7
# Accuracy:  0.74875
# Epoch:  8
# Accuracy:  0.82095
# Testing task:  1
# Accuracy:  0.74725
# Testing task:  2
# Accuracy:  0.4985
# Testing task:  3
# Accuracy:  0.4695
# Testing task:  4
# Accuracy:  0.4955
# Training task:  2
# Epoch:  0
# Accuracy:  0.7714
# Epoch:  1
# Accuracy:  0.832
# Testing task:  1
# Accuracy:  0.62275
# Testing task:  2
# Accuracy:  0.8265
# Testing task:  3
# Accuracy:  0.499
# Testing task:  4
# Accuracy:  0.517
# Training task:  3
# Epoch:  0
# Accuracy:  0.8754
# Testing task:  1
# Accuracy:  0.61625
# Testing task:  2
# Accuracy:  0.824
# Testing task:  3
# Accuracy:  0.878
# Testing task:  4
# Accuracy:  0.5
# Training task:  4
# Epoch:  0
# Accuracy:  0.7055
# Epoch:  1
# Accuracy:  0.9032
# Testing task:  1
# Accuracy:  0.6315
# Testing task:  2
# Accuracy:  0.7875
# Testing task:  3
# Accuracy:  0.906
# Testing task:  4
# Accuracy:  0.8985
# [0.74725, 0.4985, 0.4695, 0.4955, 0.62275, 0.8265, 0.499, 0.517, 0.61625, 0.824, 0.878, 0.5, 0.6315, 0.7875, 0.906, 0.8985]
# new ordering of classes:  ['ship', 'cat', 'frog', 'dog', 'bird', 'horse', 'deer', 'truck', 'airplane', 'automobile']
# Training task:  1
# Epoch:  0
# Accuracy:  0.5741
# Epoch:  1
# Accuracy:  0.64095
# Epoch:  2
# Accuracy:  0.66735
# Epoch:  3
# Accuracy:  0.717
# Epoch:  4
# Accuracy:  0.74105
# Epoch:  5
# Accuracy:  0.7749
# Epoch:  6
# Accuracy:  0.71335
# Epoch:  7
# Accuracy:  0.78675
# Epoch:  8
# Accuracy:  0.78955
# Epoch:  9
# Accuracy:  0.81415
# Testing task:  1
# Accuracy:  0.71775
# Testing task:  2
# Accuracy:  0.5
# Testing task:  3
# Accuracy:  0.5305
# Testing task:  4
# Accuracy:  0.5245
# Training task:  2
# Epoch:  0
# Accuracy:  0.7145
# Epoch:  1
# Accuracy:  0.8141
# Testing task:  1
# Accuracy:  0.628
# Testing task:  2
# Accuracy:  0.811
# Testing task:  3
# Accuracy:  0.5
# Testing task:  4
# Accuracy:  0.475
# Training task:  3
# Epoch:  0
# Accuracy:  0.9065
# Testing task:  1
# Accuracy:  0.61075
# Testing task:  2
# Accuracy:  0.8105
# Testing task:  3
# Accuracy:  0.9105
# Testing task:  4
# Accuracy:  0.495
# Training task:  4
# Epoch:  0
# Accuracy:  0.8562
# Testing task:  1
# Accuracy:  0.61175
# Testing task:  2
# Accuracy:  0.804
# Testing task:  3
# Accuracy:  0.9115
# Testing task:  4
# Accuracy:  0.8485
# [0.71775, 0.5, 0.5305, 0.5245, 0.628, 0.811, 0.5, 0.475, 0.61075, 0.8105, 0.9105, 0.495, 0.61175, 0.804, 0.9115, 0.8485]
# new ordering of classes:  ['ship', 'cat', 'frog', 'dog', 'bird', 'horse', 'deer', 'truck', 'airplane', 'automobile']
# Training task:  1
# Epoch:  0
# Accuracy:  0.57065
# Epoch:  1
# Accuracy:  0.6671
# Epoch:  2
# Accuracy:  0.70795
# Epoch:  3
# Accuracy:  0.73895
# Epoch:  4
# Accuracy:  0.74115
# Epoch:  5
# Accuracy:  0.77015
# Epoch:  6
# Accuracy:  0.77245
# Epoch:  7
# Accuracy:  0.81135
# Testing task:  1
# Accuracy:  0.745
# Testing task:  2
# Accuracy:  0.5385
# Testing task:  3
# Accuracy:  0.4065
# Testing task:  4
# Accuracy:  0.5
# Training task:  2
# Epoch:  0
# Accuracy:  0.8366
# Testing task:  1
# Accuracy:  0.4235
# Testing task:  2
# Accuracy:  0.835
# Testing task:  3
# Accuracy:  0.498
# Testing task:  4
# Accuracy:  0.5
# Training task:  3
# Epoch:  0
# Accuracy:  0.9007
# Testing task:  1
# Accuracy:  0.36825
# Testing task:  2
# Accuracy:  0.689
# Testing task:  3
# Accuracy:  0.906
# Testing task:  4
# Accuracy:  0.5
# Training task:  4
# Epoch:  0
# Accuracy:  0.8058
# Testing task:  1
# Accuracy:  0.27225
# Testing task:  2
# Accuracy:  0.6915
# Testing task:  3
# Accuracy:  0.6985
# Testing task:  4
# Accuracy:  0.8255
# [0.745, 0.5385, 0.4065, 0.5, 0.4235, 0.835, 0.498, 0.5, 0.36825, 0.689, 0.906, 0.5, 0.27225, 0.6915, 0.6985, 0.8255]
# Run 3
# new ordering of classes:  ['bird', 'truck', 'automobile', 'airplane', 'dog', 'deer', 'cat', 'ship', 'frog', 'horse']
# Training task:  1
# Epoch:  0
# Accuracy:  0.5803
# Epoch:  1
# Accuracy:  0.70295
# Epoch:  2
# Accuracy:  0.722
# Epoch:  3
# Accuracy:  0.79755
# Epoch:  4
# Accuracy:  0.81985
# Testing task:  1
# Accuracy:  0.77375
# Testing task:  2
# Accuracy:  0.4965
# Testing task:  3
# Accuracy:  0.361
# Testing task:  4
# Accuracy:  0.4945
# Training task:  2
# Epoch:  0
# Accuracy:  0.5006
# Epoch:  1
# Accuracy:  0.7123
# Epoch:  2
# Accuracy:  0.8322
# Testing task:  1
# Accuracy:  0.64875
# Testing task:  2
# Accuracy:  0.8035
# Testing task:  3
# Accuracy:  0.4245
# Testing task:  4
# Accuracy:  0.5295
# Training task:  3
# Epoch:  0
# Accuracy:  0.9245
# Testing task:  1
# Accuracy:  0.71325
# Testing task:  2
# Accuracy:  0.8145
# Testing task:  3
# Accuracy:  0.906
# Testing task:  4
# Accuracy:  0.602
# Training task:  4
# Epoch:  0
# Accuracy:  0.8529
# Testing task:  1
# Accuracy:  0.67175
# Testing task:  2
# Accuracy:  0.813
# Testing task:  3
# Accuracy:  0.908
# Testing task:  4
# Accuracy:  0.857
# [0.77375, 0.4965, 0.361, 0.4945, 0.64875, 0.8035, 0.4245, 0.5295, 0.71325, 0.8145, 0.906, 0.602, 0.67175, 0.813, 0.908, 0.857]
# new ordering of classes:  ['bird', 'truck', 'automobile', 'airplane', 'dog', 'deer', 'cat', 'ship', 'frog', 'horse']
# Training task:  1
# Epoch:  0
# Accuracy:  0.62415
# Epoch:  1
# Accuracy:  0.69975
# Epoch:  2
# Accuracy:  0.73405
# Epoch:  3
# Accuracy:  0.79615
# Epoch:  4
# Accuracy:  0.7991
# Epoch:  5
# Accuracy:  0.83825
# Testing task:  1
# Accuracy:  0.78475
# Testing task:  2
# Accuracy:  0.5435
# Testing task:  3
# Accuracy:  0.3055
# Testing task:  4
# Accuracy:  0.4905
# Training task:  2
# Epoch:  0
# Accuracy:  0.7127
# Epoch:  1
# Accuracy:  0.8082
# Testing task:  1
# Accuracy:  0.69425
# Testing task:  2
# Accuracy:  0.797
# Testing task:  3
# Accuracy:  0.4145
# Testing task:  4
# Accuracy:  0.493
# Training task:  3
# Epoch:  0
# Accuracy:  0.9385
# Testing task:  1
# Accuracy:  0.74475
# Testing task:  2
# Accuracy:  0.812
# Testing task:  3
# Accuracy:  0.927
# Testing task:  4
# Accuracy:  0.474
# Training task:  4
# Epoch:  0
# Accuracy:  0.8384
# Testing task:  1
# Accuracy:  0.6665
# Testing task:  2
# Accuracy:  0.754
# Testing task:  3
# Accuracy:  0.9105
# Testing task:  4
# Accuracy:  0.841
# [0.78475, 0.5435, 0.3055, 0.4905, 0.69425, 0.797, 0.4145, 0.493, 0.74475, 0.812, 0.927, 0.474, 0.6665, 0.754, 0.9105, 0.841]
# new ordering of classes:  ['bird', 'truck', 'automobile', 'airplane', 'dog', 'deer', 'cat', 'ship', 'frog', 'horse']
# Training task:  1
# Epoch:  0
# Accuracy:  0.5739
# Epoch:  1
# Accuracy:  0.6615
# Epoch:  2
# Accuracy:  0.76735
# Epoch:  3
# Accuracy:  0.7893
# Epoch:  4
# Accuracy:  0.8225
# Testing task:  1
# Accuracy:  0.7735
# Testing task:  2
# Accuracy:  0.507
# Testing task:  3
# Accuracy:  0.426
# Testing task:  4
# Accuracy:  0.4835
# Training task:  2
# Epoch:  0
# Accuracy:  0.6356
# Epoch:  1
# Accuracy:  0.7787
# Epoch:  2
# Accuracy:  0.8416
# Testing task:  1
# Accuracy:  0.73525
# Testing task:  2
# Accuracy:  0.806
# Testing task:  3
# Accuracy:  0.51
# Testing task:  4
# Accuracy:  0.544
# Training task:  3
# Epoch:  0
# Accuracy:  0.9372
# Testing task:  1
# Accuracy:  0.6985
# Testing task:  2
# Accuracy:  0.7895
# Testing task:  3
# Accuracy:  0.9275
# Testing task:  4
# Accuracy:  0.5855
# Training task:  4
# Epoch:  0
# Accuracy:  0.8715
# Testing task:  1
# Accuracy:  0.6645
# Testing task:  2
# Accuracy:  0.8145
# Testing task:  3
# Accuracy:  0.9085
# Testing task:  4
# Accuracy:  0.8695
# [0.7735, 0.507, 0.426, 0.4835, 0.73525, 0.806, 0.51, 0.544, 0.6985, 0.7895, 0.9275, 0.5855, 0.6645, 0.8145, 0.9085, 0.8695]
# new ordering of classes:  ['bird', 'truck', 'automobile', 'airplane', 'dog', 'deer', 'cat', 'ship', 'frog', 'horse']
# Training task:  1
# Epoch:  0
# Accuracy:  0.56085
# Epoch:  1
# Accuracy:  0.6323
# Epoch:  2
# Accuracy:  0.74425
# Epoch:  3
# Accuracy:  0.7994
# Epoch:  4
# Accuracy:  0.8246
# Testing task:  1
# Accuracy:  0.78075
# Testing task:  2
# Accuracy:  0.5115
# Testing task:  3
# Accuracy:  0.5225
# Testing task:  4
# Accuracy:  0.463
# Training task:  2
# Epoch:  0
# Accuracy:  0.761
# Epoch:  1
# Accuracy:  0.8048
# Testing task:  1
# Accuracy:  0.54625
# Testing task:  2
# Accuracy:  0.8045
# Testing task:  3
# Accuracy:  0.3755
# Testing task:  4
# Accuracy:  0.5035
# Training task:  3
# Epoch:  0
# Accuracy:  0.9266
# Testing task:  1
# Accuracy:  0.58675
# Testing task:  2
# Accuracy:  0.601
# Testing task:  3
# Accuracy:  0.916
# Testing task:  4
# Accuracy:  0.476
# Training task:  4
# Epoch:  0
# Accuracy:  0.8297
# Testing task:  1
# Accuracy:  0.50675
# Testing task:  2
# Accuracy:  0.6365
# Testing task:  3
# Accuracy:  0.8755
# Testing task:  4
# Accuracy:  0.8425
# [0.78075, 0.5115, 0.5225, 0.463, 0.54625, 0.8045, 0.3755, 0.5035, 0.58675, 0.601, 0.916, 0.476, 0.50675, 0.6365, 0.8755, 0.8425]
# Run 4
# new ordering of classes:  ['ship', 'automobile', 'airplane', 'horse', 'truck', 'deer', 'cat', 'frog', 'bird', 'dog']
# Training task:  1
# Epoch:  0
# Accuracy:  0.65055
# Epoch:  1
# Accuracy:  0.7226
# Epoch:  2
# Accuracy:  0.77195
# Epoch:  3
# Accuracy:  0.8343
# Testing task:  1
# Accuracy:  0.81125
# Testing task:  2
# Accuracy:  0.451
# Testing task:  3
# Accuracy:  0.494
# Testing task:  4
# Accuracy:  0.495
# Training task:  2
# Epoch:  0
# Accuracy:  0.9319
# Testing task:  1
# Accuracy:  0.80325
# Testing task:  2
# Accuracy:  0.942
# Testing task:  3
# Accuracy:  0.5155
# Testing task:  4
# Accuracy:  0.4945
# Training task:  3
# Epoch:  0
# Accuracy:  0.7143
# Epoch:  1
# Accuracy:  0.7515
# Epoch:  2
# Accuracy:  0.6608
# Epoch:  3
# Accuracy:  0.6911
# Epoch:  4
# Accuracy:  0.8284
# Testing task:  1
# Accuracy:  0.72475
# Testing task:  2
# Accuracy:  0.9165
# Testing task:  3
# Accuracy:  0.8245
# Testing task:  4
# Accuracy:  0.4495
# Training task:  4
# Epoch:  0
# Accuracy:  0.7599
# Epoch:  1
# Accuracy:  0.7505
# Epoch:  2
# Accuracy:  0.8084
# Testing task:  1
# Accuracy:  0.75275
# Testing task:  2
# Accuracy:  0.9265
# Testing task:  3
# Accuracy:  0.8055
# Testing task:  4
# Accuracy:  0.7965
# [0.81125, 0.451, 0.494, 0.495, 0.80325, 0.942, 0.5155, 0.4945, 0.72475, 0.9165, 0.8245, 0.4495, 0.75275, 0.9265, 0.8055, 0.7965]
# new ordering of classes:  ['ship', 'automobile', 'airplane', 'horse', 'truck', 'deer', 'cat', 'frog', 'bird', 'dog']
# Training task:  1
# Epoch:  0
# Accuracy:  0.55695
# Epoch:  1
# Accuracy:  0.73935
# Epoch:  2
# Accuracy:  0.76665
# Epoch:  3
# Accuracy:  0.80445
# Testing task:  1
# Accuracy:  0.79025
# Testing task:  2
# Accuracy:  0.5
# Testing task:  3
# Accuracy:  0.549
# Testing task:  4
# Accuracy:  0.419
# Training task:  2
# Epoch:  0
# Accuracy:  0.9414
# Testing task:  1
# Accuracy:  0.70975
# Testing task:  2
# Accuracy:  0.9465
# Testing task:  3
# Accuracy:  0.5275
# Testing task:  4
# Accuracy:  0.445
# Training task:  3
# Epoch:  0
# Accuracy:  0.646
# Epoch:  1
# Accuracy:  0.7024
# Epoch:  2
# Accuracy:  0.811
# Testing task:  1
# Accuracy:  0.7325
# Testing task:  2
# Accuracy:  0.9135
# Testing task:  3
# Accuracy:  0.795
# Testing task:  4
# Accuracy:  0.4285
# Training task:  4
# Epoch:  0
# Accuracy:  0.748
# Epoch:  1
# Accuracy:  0.7732
# Epoch:  2
# Accuracy:  0.828
# Testing task:  1
# Accuracy:  0.7255
# Testing task:  2
# Accuracy:  0.916
# Testing task:  3
# Accuracy:  0.7785
# Testing task:  4
# Accuracy:  0.797
# [0.79025, 0.5, 0.549, 0.419, 0.70975, 0.9465, 0.5275, 0.445, 0.7325, 0.9135, 0.795, 0.4285, 0.7255, 0.916, 0.7785, 0.797]
# new ordering of classes:  ['ship', 'automobile', 'airplane', 'horse', 'truck', 'deer', 'cat', 'frog', 'bird', 'dog']
# Training task:  1
# Epoch:  0
# Accuracy:  0.58705
# Epoch:  1
# Accuracy:  0.71945
# Epoch:  2
# Accuracy:  0.7622
# Epoch:  3
# Accuracy:  0.82905
# Testing task:  1
# Accuracy:  0.8115
# Testing task:  2
# Accuracy:  0.4965
# Testing task:  3
# Accuracy:  0.5025
# Testing task:  4
# Accuracy:  0.4985
# Training task:  2
# Epoch:  0
# Accuracy:  0.8438
# Testing task:  1
# Accuracy:  0.5015
# Testing task:  2
# Accuracy:  0.8495
# Testing task:  3
# Accuracy:  0.499
# Testing task:  4
# Accuracy:  0.4715
# Training task:  3
# Epoch:  0
# Accuracy:  0.6067
# Epoch:  1
# Accuracy:  0.6861
# Epoch:  2
# Accuracy:  0.6987
# Epoch:  3
# Accuracy:  0.8082
# Testing task:  1
# Accuracy:  0.65225
# Testing task:  2
# Accuracy:  0.895
# Testing task:  3
# Accuracy:  0.7915
# Testing task:  4
# Accuracy:  0.521
# Training task:  4
# Epoch:  0
# Accuracy:  0.6864
# Epoch:  1
# Accuracy:  0.7445
# Epoch:  2
# Accuracy:  0.806
# Testing task:  1
# Accuracy:  0.65375
# Testing task:  2
# Accuracy:  0.896
# Testing task:  3
# Accuracy:  0.788
# Testing task:  4
# Accuracy:  0.7705
# [0.8115, 0.4965, 0.5025, 0.4985, 0.5015, 0.8495, 0.499, 0.4715, 0.65225, 0.895, 0.7915, 0.521, 0.65375, 0.896, 0.788, 0.7705]
# new ordering of classes:  ['ship', 'automobile', 'airplane', 'horse', 'truck', 'deer', 'cat', 'frog', 'bird', 'dog']
# Training task:  1
# Epoch:  0
# Accuracy:  0.6035
# Epoch:  1
# Accuracy:  0.6897
# Epoch:  2
# Accuracy:  0.76595
# Epoch:  3
# Accuracy:  0.77015
# Epoch:  4
# Accuracy:  0.85315
# Testing task:  1
# Accuracy:  0.8165
# Testing task:  2
# Accuracy:  0.481
# Testing task:  3
# Accuracy:  0.4995
# Testing task:  4
# Accuracy:  0.481
# Training task:  2
# Epoch:  0
# Accuracy:  0.9424
# Testing task:  1
# Accuracy:  0.68775
# Testing task:  2
# Accuracy:  0.95
# Testing task:  3
# Accuracy:  0.5
# Testing task:  4
# Accuracy:  0.5
# Training task:  3
# Epoch:  0
# Accuracy:  0.6937
# Epoch:  1
# Accuracy:  0.7667
# Epoch:  2
# Accuracy:  0.7876
# Epoch:  3
# Accuracy:  0.8435
# Testing task:  1
# Accuracy:  0.5275
# Testing task:  2
# Accuracy:  0.8625
# Testing task:  3
# Accuracy:  0.83
# Testing task:  4
# Accuracy:  0.5035
# Training task:  4
# Epoch:  0
# Accuracy:  0.788
# Epoch:  1
# Accuracy:  0.8119
# Testing task:  1
# Accuracy:  0.29325
# Testing task:  2
# Accuracy:  0.7465
# Testing task:  3
# Accuracy:  0.747
# Testing task:  4
# Accuracy:  0.7895
# [0.8165, 0.481, 0.4995, 0.481, 0.68775, 0.95, 0.5, 0.5, 0.5275, 0.8625, 0.83, 0.5035, 0.29325, 0.7465, 0.747, 0.7895]
# Run 5
# new ordering of classes:  ['bird', 'horse', 'dog', 'truck', 'airplane', 'ship', 'automobile', 'frog', 'cat', 'deer']
# Training task:  1
# Epoch:  0
# Accuracy:  0.61725
# Epoch:  1
# Accuracy:  0.67175
# Epoch:  2
# Accuracy:  0.73415
# Epoch:  3
# Accuracy:  0.7376
# Epoch:  4
# Accuracy:  0.7983
# Epoch:  5
# Accuracy:  0.83755
# Testing task:  1
# Accuracy:  0.7815
# Testing task:  2
# Accuracy:  0.496
# Testing task:  3
# Accuracy:  0.6375
# Testing task:  4
# Accuracy:  0.4995
# Training task:  2
# Epoch:  0
# Accuracy:  0.6575
# Epoch:  1
# Accuracy:  0.7762
# Epoch:  2
# Accuracy:  0.6579
# Epoch:  3
# Accuracy:  0.7976
# Epoch:  4
# Accuracy:  0.8532
# Testing task:  1
# Accuracy:  0.6335
# Testing task:  2
# Accuracy:  0.822
# Testing task:  3
# Accuracy:  0.5945
# Testing task:  4
# Accuracy:  0.5005
# Training task:  3
# Epoch:  0
# Accuracy:  0.9028
# Testing task:  1
# Accuracy:  0.69525
# Testing task:  2
# Accuracy:  0.8
# Testing task:  3
# Accuracy:  0.902
# Testing task:  4
# Accuracy:  0.497
# Training task:  4
# Epoch:  0
# Accuracy:  0.7724
# Epoch:  1
# Accuracy:  0.6732
# Epoch:  2
# Accuracy:  0.8429
# Testing task:  1
# Accuracy:  0.656
# Testing task:  2
# Accuracy:  0.732
# Testing task:  3
# Accuracy:  0.8645
# Testing task:  4
# Accuracy:  0.827
# [0.7815, 0.496, 0.6375, 0.4995, 0.6335, 0.822, 0.5945, 0.5005, 0.69525, 0.8, 0.902, 0.497, 0.656, 0.732, 0.8645, 0.827]
# new ordering of classes:  ['bird', 'horse', 'dog', 'truck', 'airplane', 'ship', 'automobile', 'frog', 'cat', 'deer']
# Training task:  1
# Epoch:  0
# Accuracy:  0.601
# Epoch:  1
# Accuracy:  0.687
# Epoch:  2
# Accuracy:  0.7304
# Epoch:  3
# Accuracy:  0.7802
# Epoch:  4
# Accuracy:  0.77385
# Epoch:  5
# Accuracy:  0.80145
# Testing task:  1
# Accuracy:  0.75075
# Testing task:  2
# Accuracy:  0.499
# Testing task:  3
# Accuracy:  0.73
# Testing task:  4
# Accuracy:  0.622
# Training task:  2
# Epoch:  0
# Accuracy:  0.7372
# Epoch:  1
# Accuracy:  0.8231
# Testing task:  1
# Accuracy:  0.62875
# Testing task:  2
# Accuracy:  0.815
# Testing task:  3
# Accuracy:  0.562
# Testing task:  4
# Accuracy:  0.559
# Training task:  3
# Epoch:  0
# Accuracy:  0.9436
# Testing task:  1
# Accuracy:  0.7235
# Testing task:  2
# Accuracy:  0.78
# Testing task:  3
# Accuracy:  0.9375
# Testing task:  4
# Accuracy:  0.6285
# Training task:  4
# Epoch:  0
# Accuracy:  0.6627
# Epoch:  1
# Accuracy:  0.7896
# Epoch:  2
# Accuracy:  0.8557
# Testing task:  1
# Accuracy:  0.72625
# Testing task:  2
# Accuracy:  0.784
# Testing task:  3
# Accuracy:  0.9315
# Testing task:  4
# Accuracy:  0.816
# [0.75075, 0.499, 0.73, 0.622, 0.62875, 0.815, 0.562, 0.559, 0.7235, 0.78, 0.9375, 0.6285, 0.72625, 0.784, 0.9315, 0.816]
# new ordering of classes:  ['bird', 'horse', 'dog', 'truck', 'airplane', 'ship', 'automobile', 'frog', 'cat', 'deer']
# Training task:  1
# Epoch:  0
# Accuracy:  0.6455
# Epoch:  1
# Accuracy:  0.7049
# Epoch:  2
# Accuracy:  0.7416
# Epoch:  3
# Accuracy:  0.7608
# Epoch:  4
# Accuracy:  0.7997
# Epoch:  5
# Accuracy:  0.8465
# Testing task:  1
# Accuracy:  0.781
# Testing task:  2
# Accuracy:  0.4335
# Testing task:  3
# Accuracy:  0.4925
# Testing task:  4
# Accuracy:  0.5095
# Training task:  2
# Epoch:  0
# Accuracy:  0.6838
# Epoch:  1
# Accuracy:  0.726
# Epoch:  2
# Accuracy:  0.8229
# Testing task:  1
# Accuracy:  0.69125
# Testing task:  2
# Accuracy:  0.796
# Testing task:  3
# Accuracy:  0.496
# Testing task:  4
# Accuracy:  0.512
# Training task:  3
# Epoch:  0
# Accuracy:  0.9526
# Testing task:  1
# Accuracy:  0.66025
# Testing task:  2
# Accuracy:  0.78
# Testing task:  3
# Accuracy:  0.9485
# Testing task:  4
# Accuracy:  0.5535
# Training task:  4
# Epoch:  0
# Accuracy:  0.7684
# Epoch:  1
# Accuracy:  0.8331
# Testing task:  1
# Accuracy:  0.6925
# Testing task:  2
# Accuracy:  0.7615
# Testing task:  3
# Accuracy:  0.9395
# Testing task:  4
# Accuracy:  0.811
# [0.781, 0.4335, 0.4925, 0.5095, 0.69125, 0.796, 0.496, 0.512, 0.66025, 0.78, 0.9485, 0.5535, 0.6925, 0.7615, 0.9395, 0.811]
# new ordering of classes:  ['bird', 'horse', 'dog', 'truck', 'airplane', 'ship', 'automobile', 'frog', 'cat', 'deer']
# Training task:  1
# Epoch:  0
# Accuracy:  0.5497
# Epoch:  1
# Accuracy:  0.6564
# Epoch:  2
# Accuracy:  0.7118
# Epoch:  3
# Accuracy:  0.75775
# Epoch:  4
# Accuracy:  0.80485
# Testing task:  1
# Accuracy:  0.74375
# Testing task:  2
# Accuracy:  0.5
# Testing task:  3
# Accuracy:  0.499
# Testing task:  4
# Accuracy:  0.498
# Training task:  2
# Epoch:  0
# Accuracy:  0.7157
# Epoch:  1
# Accuracy:  0.8229
# Testing task:  1
# Accuracy:  0.5705
# Testing task:  2
# Accuracy:  0.809
# Testing task:  3
# Accuracy:  0.4975
# Testing task:  4
# Accuracy:  0.4975
# Training task:  3
# Epoch:  0
# Accuracy:  0.9395
# Testing task:  1
# Accuracy:  0.5915
# Testing task:  2
# Accuracy:  0.666
# Testing task:  3
# Accuracy:  0.9425
# Testing task:  4
# Accuracy:  0.503
# Training task:  4
# Epoch:  0
# Accuracy:  0.7161
# Epoch:  1
# Accuracy:  0.7929
# Epoch:  2
# Accuracy:  0.7959
# Epoch:  3
# Accuracy:  0.8286
# Testing task:  1
# Accuracy:  0.50225
# Testing task:  2
# Accuracy:  0.549
# Testing task:  3
# Accuracy:  0.798
# Testing task:  4
# Accuracy:  0.81
# [0.74375, 0.5, 0.499, 0.498, 0.5705, 0.809, 0.4975, 0.4975, 0.5915, 0.666, 0.9425, 0.503, 0.50225, 0.549, 0.798, 0.81]
# Run 6
# new ordering of classes:  ['ship', 'airplane', 'frog', 'bird', 'truck', 'automobile', 'horse', 'deer', 'dog', 'cat']
# Training task:  1
# Epoch:  0
# Accuracy:  0.54255
# Epoch:  1
# Accuracy:  0.6046
# Epoch:  2
# Accuracy:  0.71275
# Epoch:  3
# Accuracy:  0.73955
# Epoch:  4
# Accuracy:  0.7784
# Epoch:  5
# Accuracy:  0.7758
# Epoch:  6
# Accuracy:  0.82275
# Testing task:  1
# Accuracy:  0.78275
# Testing task:  2
# Accuracy:  0.5195
# Testing task:  3
# Accuracy:  0.4815
# Testing task:  4
# Accuracy:  0.5145
# Training task:  2
# Epoch:  0
# Accuracy:  0.7989
# Epoch:  1
# Accuracy:  0.7493
# Epoch:  2
# Accuracy:  0.8485
# Testing task:  1
# Accuracy:  0.7045
# Testing task:  2
# Accuracy:  0.833
# Testing task:  3
# Accuracy:  0.4855
# Testing task:  4
# Accuracy:  0.5155
# Training task:  3
# Epoch:  0
# Accuracy:  0.5058
# Epoch:  1
# Accuracy:  0.6316
# Epoch:  2
# Accuracy:  0.7057
# Epoch:  3
# Accuracy:  0.753
# Epoch:  4
# Accuracy:  0.8513
# Testing task:  1
# Accuracy:  0.61675
# Testing task:  2
# Accuracy:  0.8375
# Testing task:  3
# Accuracy:  0.8145
# Testing task:  4
# Accuracy:  0.5415
# Training task:  4
# Epoch:  0
# Accuracy:  0.6293
# Epoch:  1
# Accuracy:  0.6647
# Epoch:  2
# Accuracy:  0.7023
# Epoch:  3
# Accuracy:  0.6242
# Epoch:  4
# Accuracy:  0.7517
# Epoch:  5
# Accuracy:  0.8024
# Testing task:  1
# Accuracy:  0.572
# Testing task:  2
# Accuracy:  0.795
# Testing task:  3
# Accuracy:  0.726
# Testing task:  4
# Accuracy:  0.724
# [0.78275, 0.5195, 0.4815, 0.5145, 0.7045, 0.833, 0.4855, 0.5155, 0.61675, 0.8375, 0.8145, 0.5415, 0.572, 0.795, 0.726, 0.724]
# new ordering of classes:  ['ship', 'airplane', 'frog', 'bird', 'truck', 'automobile', 'horse', 'deer', 'dog', 'cat']
# Training task:  1
# Epoch:  0
# Accuracy:  0.4855
# Epoch:  1
# Accuracy:  0.62085
# Epoch:  2
# Accuracy:  0.65955
# Epoch:  3
# Accuracy:  0.72975
# Epoch:  4
# Accuracy:  0.73355
# Epoch:  5
# Accuracy:  0.72975
# Epoch:  6
# Accuracy:  0.8161
# Testing task:  1
# Accuracy:  0.76675
# Testing task:  2
# Accuracy:  0.5265
# Testing task:  3
# Accuracy:  0.502
# Testing task:  4
# Accuracy:  0.489
# Training task:  2
# Epoch:  0
# Accuracy:  0.7695
# Epoch:  1
# Accuracy:  0.8155
# Testing task:  1
# Accuracy:  0.695
# Testing task:  2
# Accuracy:  0.804
# Testing task:  3
# Accuracy:  0.506
# Testing task:  4
# Accuracy:  0.512
# Training task:  3
# Epoch:  0
# Accuracy:  0.7791
# Epoch:  1
# Accuracy:  0.7711
# Epoch:  2
# Accuracy:  0.8359
# Testing task:  1
# Accuracy:  0.689
# Testing task:  2
# Accuracy:  0.785
# Testing task:  3
# Accuracy:  0.817
# Testing task:  4
# Accuracy:  0.476
# Training task:  4
# Epoch:  0
# Accuracy:  0.5808
# Epoch:  1
# Accuracy:  0.6086
# Epoch:  2
# Accuracy:  0.7401
# Epoch:  3
# Accuracy:  0.769
# Epoch:  4
# Accuracy:  0.8028
# Testing task:  1
# Accuracy:  0.6575
# Testing task:  2
# Accuracy:  0.7425
# Testing task:  3
# Accuracy:  0.7565
# Testing task:  4
# Accuracy:  0.713
# [0.76675, 0.5265, 0.502, 0.489, 0.695, 0.804, 0.506, 0.512, 0.689, 0.785, 0.817, 0.476, 0.6575, 0.7425, 0.7565, 0.713]
# new ordering of classes:  ['ship', 'airplane', 'frog', 'bird', 'truck', 'automobile', 'horse', 'deer', 'dog', 'cat']
# Training task:  1
# Epoch:  0
# Accuracy:  0.562
# Epoch:  1
# Accuracy:  0.5846
# Epoch:  2
# Accuracy:  0.69395
# Epoch:  3
# Accuracy:  0.734
# Epoch:  4
# Accuracy:  0.7602
# Epoch:  5
# Accuracy:  0.8121
# Testing task:  1
# Accuracy:  0.7705
# Testing task:  2
# Accuracy:  0.4805
# Testing task:  3
# Accuracy:  0.501
# Testing task:  4
# Accuracy:  0.4995
# Training task:  2
# Epoch:  0
# Accuracy:  0.506
# Epoch:  1
# Accuracy:  0.7089
# Epoch:  2
# Accuracy:  0.8588
# Testing task:  1
# Accuracy:  0.7035
# Testing task:  2
# Accuracy:  0.837
# Testing task:  3
# Accuracy:  0.5055
# Testing task:  4
# Accuracy:  0.5005
# Training task:  3
# Epoch:  0
# Accuracy:  0.7743
# Epoch:  1
# Accuracy:  0.8305
# Testing task:  1
# Accuracy:  0.6845
# Testing task:  2
# Accuracy:  0.8115
# Testing task:  3
# Accuracy:  0.8185
# Testing task:  4
# Accuracy:  0.4845
# Training task:  4
# Epoch:  0
# Accuracy:  0.6457
# Epoch:  1
# Accuracy:  0.715
# Epoch:  2
# Accuracy:  0.7544
# Epoch:  3
# Accuracy:  0.7295
# Epoch:  4
# Accuracy:  0.8318
# Testing task:  1
# Accuracy:  0.6345
# Testing task:  2
# Accuracy:  0.7895
# Testing task:  3
# Accuracy:  0.749
# Testing task:  4
# Accuracy:  0.733
# [0.7705, 0.4805, 0.501, 0.4995, 0.7035, 0.837, 0.5055, 0.5005, 0.6845, 0.8115, 0.8185, 0.4845, 0.6345, 0.7895, 0.749, 0.733]
# new ordering of classes:  ['ship', 'airplane', 'frog', 'bird', 'truck', 'automobile', 'horse', 'deer', 'dog', 'cat']
# Training task:  1
# Epoch:  0
# Accuracy:  0.58015
# Epoch:  1
# Accuracy:  0.5327
# Epoch:  2
# Accuracy:  0.65415
# Epoch:  3
# Accuracy:  0.7144
# Epoch:  4
# Accuracy:  0.7275
# Epoch:  5
# Accuracy:  0.7651
# Epoch:  6
# Accuracy:  0.8228
# Testing task:  1
# Accuracy:  0.76425
# Testing task:  2
# Accuracy:  0.5
# Testing task:  3
# Accuracy:  0.5655
# Testing task:  4
# Accuracy:  0.4745
# Training task:  2
# Epoch:  0
# Accuracy:  0.7365
# Epoch:  1
# Accuracy:  0.795
# Epoch:  2
# Accuracy:  0.8273
# Testing task:  1
# Accuracy:  0.64625
# Testing task:  2
# Accuracy:  0.8095
# Testing task:  3
# Accuracy:  0.509
# Testing task:  4
# Accuracy:  0.4885
# Training task:  3
# Epoch:  0
# Accuracy:  0.7633
# Epoch:  1
# Accuracy:  0.8201
# Testing task:  1
# Accuracy:  0.6415
# Testing task:  2
# Accuracy:  0.775
# Testing task:  3
# Accuracy:  0.8095
# Testing task:  4
# Accuracy:  0.5065
# Training task:  4
# Epoch:  0
# Accuracy:  0.6733
# Epoch:  1
# Accuracy:  0.7055
# Epoch:  2
# Accuracy:  0.7354
# Epoch:  3
# Accuracy:  0.755
# Epoch:  4
# Accuracy:  0.7846
# Epoch:  5
# Accuracy:  0.7266
# Epoch:  6
# Accuracy:  0.7714
# Epoch:  7
# Accuracy:  0.7807
# Epoch:  8
# Accuracy:  0.8079
# Testing task:  1
# Accuracy:  0.52975
# Testing task:  2
# Accuracy:  0.667
# Testing task:  3
# Accuracy:  0.683
# Testing task:  4
# Accuracy:  0.699
# [0.76425, 0.5, 0.5655, 0.4745, 0.64625, 0.8095, 0.509, 0.4885, 0.6415, 0.775, 0.8095, 0.5065, 0.52975, 0.667, 0.683, 0.699]
# Run 7
# new ordering of classes:  ['deer', 'truck', 'automobile', 'cat', 'ship', 'bird', 'dog', 'frog', 'airplane', 'horse']
# Training task:  1
# Epoch:  0
# Accuracy:  0.62905
# Epoch:  1
# Accuracy:  0.7065
# Epoch:  2
# Accuracy:  0.73175
# Epoch:  3
# Accuracy:  0.7793
# Epoch:  4
# Accuracy:  0.76645
# Epoch:  5
# Accuracy:  0.8027
# Testing task:  1
# Accuracy:  0.749
# Testing task:  2
# Accuracy:  0.499
# Testing task:  3
# Accuracy:  0.427
# Testing task:  4
# Accuracy:  0.518
# Training task:  2
# Epoch:  0
# Accuracy:  0.9186
# Testing task:  1
# Accuracy:  0.74975
# Testing task:  2
# Accuracy:  0.912
# Testing task:  3
# Accuracy:  0.4265
# Testing task:  4
# Accuracy:  0.4115
# Training task:  3
# Epoch:  0
# Accuracy:  0.7697
# Epoch:  1
# Accuracy:  0.7298
# Epoch:  2
# Accuracy:  0.8532
# Testing task:  1
# Accuracy:  0.661
# Testing task:  2
# Accuracy:  0.8865
# Testing task:  3
# Accuracy:  0.846
# Testing task:  4
# Accuracy:  0.4565
# Training task:  4
# Epoch:  0
# Accuracy:  0.8824
# Testing task:  1
# Accuracy:  0.6835
# Testing task:  2
# Accuracy:  0.908
# Testing task:  3
# Accuracy:  0.844
# Testing task:  4
# Accuracy:  0.877
# [0.749, 0.499, 0.427, 0.518, 0.74975, 0.912, 0.4265, 0.4115, 0.661, 0.8865, 0.846, 0.4565, 0.6835, 0.908, 0.844, 0.877]
# new ordering of classes:  ['deer', 'truck', 'automobile', 'cat', 'ship', 'bird', 'dog', 'frog', 'airplane', 'horse']
# Training task:  1
# Epoch:  0
# Accuracy:  0.5143
# Epoch:  1
# Accuracy:  0.69155
# Epoch:  2
# Accuracy:  0.7377
# Epoch:  3
# Accuracy:  0.73215
# Epoch:  4
# Accuracy:  0.78365
# Epoch:  5
# Accuracy:  0.8111
# Testing task:  1
# Accuracy:  0.753
# Testing task:  2
# Accuracy:  0.7145
# Testing task:  3
# Accuracy:  0.5
# Testing task:  4
# Accuracy:  0.4235
# Training task:  2
# Epoch:  0
# Accuracy:  0.9249
# Testing task:  1
# Accuracy:  0.74475
# Testing task:  2
# Accuracy:  0.9175
# Testing task:  3
# Accuracy:  0.4995
# Testing task:  4
# Accuracy:  0.4415
# Training task:  3
# Epoch:  0
# Accuracy:  0.8206
# Testing task:  1
# Accuracy:  0.57675
# Testing task:  2
# Accuracy:  0.841
# Testing task:  3
# Accuracy:  0.826
# Testing task:  4
# Accuracy:  0.4335
# Training task:  4
# Epoch:  0
# Accuracy:  0.8888
# Testing task:  1
# Accuracy:  0.63375
# Testing task:  2
# Accuracy:  0.854
# Testing task:  3
# Accuracy:  0.757
# Testing task:  4
# Accuracy:  0.891
# [0.753, 0.7145, 0.5, 0.4235, 0.74475, 0.9175, 0.4995, 0.4415, 0.57675, 0.841, 0.826, 0.4335, 0.63375, 0.854, 0.757, 0.891]
# new ordering of classes:  ['deer', 'truck', 'automobile', 'cat', 'ship', 'bird', 'dog', 'frog', 'airplane', 'horse']
# Training task:  1
# Epoch:  0
# Accuracy:  0.5932
# Epoch:  1
# Accuracy:  0.64525
# Epoch:  2
# Accuracy:  0.73365
# Epoch:  3
# Accuracy:  0.77665
# Epoch:  4
# Accuracy:  0.75775
# Epoch:  5
# Accuracy:  0.8285
# Testing task:  1
# Accuracy:  0.777
# Testing task:  2
# Accuracy:  0.5045
# Testing task:  3
# Accuracy:  0.508
# Testing task:  4
# Accuracy:  0.5415
# Training task:  2
# Epoch:  0
# Accuracy:  0.873
# Testing task:  1
# Accuracy:  0.67425
# Testing task:  2
# Accuracy:  0.875
# Testing task:  3
# Accuracy:  0.517
# Testing task:  4
# Accuracy:  0.6155
# Training task:  3
# Epoch:  0
# Accuracy:  0.6515
# Epoch:  1
# Accuracy:  0.8138
# Testing task:  1
# Accuracy:  0.656
# Testing task:  2
# Accuracy:  0.899
# Testing task:  3
# Accuracy:  0.8125
# Testing task:  4
# Accuracy:  0.5375
# Training task:  4
# Epoch:  0
# Accuracy:  0.9094
# Testing task:  1
# Accuracy:  0.636
# Testing task:  2
# Accuracy:  0.882
# Testing task:  3
# Accuracy:  0.85
# Testing task:  4
# Accuracy:  0.909
# [0.777, 0.5045, 0.508, 0.5415, 0.67425, 0.875, 0.517, 0.6155, 0.656, 0.899, 0.8125, 0.5375, 0.636, 0.882, 0.85, 0.909]
# new ordering of classes:  ['deer', 'truck', 'automobile', 'cat', 'ship', 'bird', 'dog', 'frog', 'airplane', 'horse']
# Training task:  1
# Epoch:  0
# Accuracy:  0.4463
# Epoch:  1
# Accuracy:  0.70665
# Epoch:  2
# Accuracy:  0.6819
# Epoch:  3
# Accuracy:  0.74495
# Epoch:  4
# Accuracy:  0.801
# Testing task:  1
# Accuracy:  0.76925
# Testing task:  2
# Accuracy:  0.4975
# Testing task:  3
# Accuracy:  0.439
# Testing task:  4
# Accuracy:  0.5185
# Training task:  2
# Epoch:  0
# Accuracy:  0.9285
# Testing task:  1
# Accuracy:  0.71125
# Testing task:  2
# Accuracy:  0.9245
# Testing task:  3
# Accuracy:  0.418
# Testing task:  4
# Accuracy:  0.505
# Training task:  3
# Epoch:  0
# Accuracy:  0.8146
# Testing task:  1
# Accuracy:  0.605
# Testing task:  2
# Accuracy:  0.868
# Testing task:  3
# Accuracy:  0.8265
# Testing task:  4
# Accuracy:  0.5055
# Training task:  4
# Epoch:  0
# Accuracy:  0.9237
# Testing task:  1
# Accuracy:  0.6505
# Testing task:  2
# Accuracy:  0.8715
# Testing task:  3
# Accuracy:  0.7685
# Testing task:  4
# Accuracy:  0.92
# [0.76925, 0.4975, 0.439, 0.5185, 0.71125, 0.9245, 0.418, 0.505, 0.605, 0.868, 0.8265, 0.5055, 0.6505, 0.8715, 0.7685, 0.92]
# Run 8
# new ordering of classes:  ['truck', 'airplane', 'bird', 'deer', 'automobile', 'horse', 'cat', 'dog', 'ship', 'frog']
# Training task:  1
# Epoch:  0
# Accuracy:  0.55445
# Epoch:  1
# Accuracy:  0.6654
# Epoch:  2
# Accuracy:  0.6777
# Epoch:  3
# Accuracy:  0.7097
# Epoch:  4
# Accuracy:  0.722
# Epoch:  5
# Accuracy:  0.6487
# Epoch:  6
# Accuracy:  0.7841
# Epoch:  7
# Accuracy:  0.8281
# Testing task:  1
# Accuracy:  0.75075
# Testing task:  2
# Accuracy:  0.5805
# Testing task:  3
# Accuracy:  0.489
# Testing task:  4
# Accuracy:  0.495
# Training task:  2
# Epoch:  0
# Accuracy:  0.9645
# Testing task:  1
# Accuracy:  0.7335
# Testing task:  2
# Accuracy:  0.955
# Testing task:  3
# Accuracy:  0.496
# Testing task:  4
# Accuracy:  0.237
# Training task:  3
# Epoch:  0
# Accuracy:  0.5
# Epoch:  1
# Accuracy:  0.5688
# Epoch:  2
# Accuracy:  0.6291
# Epoch:  3
# Accuracy:  0.6519
# Epoch:  4
# Accuracy:  0.5
# Epoch:  5
# Accuracy:  0.5029
# Epoch:  6
# Accuracy:  0.5078
# Epoch:  7
# Accuracy:  0.7333
# Epoch:  8
# Accuracy:  0.7477
# Epoch:  9
# Accuracy:  0.7271
# Testing task:  1
# Accuracy:  0.66
# Testing task:  2
# Accuracy:  0.83
# Testing task:  3
# Accuracy:  0.6545
# Testing task:  4
# Accuracy:  0.421
# Training task:  4
# Epoch:  0
# Accuracy:  0.9495
# Testing task:  1
# Accuracy:  0.7065
# Testing task:  2
# Accuracy:  0.921
# Testing task:  3
# Accuracy:  0.69
# Testing task:  4
# Accuracy:  0.9475
# [0.75075, 0.5805, 0.489, 0.495, 0.7335, 0.955, 0.496, 0.237, 0.66, 0.83, 0.6545, 0.421, 0.7065, 0.921, 0.69, 0.9475]
# new ordering of classes:  ['truck', 'airplane', 'bird', 'deer', 'automobile', 'horse', 'cat', 'dog', 'ship', 'frog']
# Training task:  1
# Epoch:  0
# Accuracy:  0.55165
# Epoch:  1
# Accuracy:  0.66055
# Epoch:  2
# Accuracy:  0.6873
# Epoch:  3
# Accuracy:  0.72225
# Epoch:  4
# Accuracy:  0.73125
# Epoch:  5
# Accuracy:  0.76765
# Epoch:  6
# Accuracy:  0.80945
# Testing task:  1
# Accuracy:  0.749
# Testing task:  2
# Accuracy:  0.301
# Testing task:  3
# Accuracy:  0.505
# Testing task:  4
# Accuracy:  0.3885
# Training task:  2
# Epoch:  0
# Accuracy:  0.9615
# Testing task:  1
# Accuracy:  0.68725
# Testing task:  2
# Accuracy:  0.9545
# Testing task:  3
# Accuracy:  0.5
# Testing task:  4
# Accuracy:  0.3905
# Training task:  3
# Epoch:  0
# Accuracy:  0.5815
# Epoch:  1
# Accuracy:  0.6224
# Epoch:  2
# Accuracy:  0.7232
# Epoch:  3
# Accuracy:  0.7131
# Epoch:  4
# Accuracy:  0.6906
# Epoch:  5
# Accuracy:  0.7077
# Epoch:  6
# Accuracy:  0.7885
# Epoch:  7
# Accuracy:  0.8265
# Testing task:  1
# Accuracy:  0.59125
# Testing task:  2
# Accuracy:  0.835
# Testing task:  3
# Accuracy:  0.6865
# Testing task:  4
# Accuracy:  0.479
# Training task:  4
# Epoch:  0
# Accuracy:  0.9597
# Testing task:  1
# Accuracy:  0.696
# Testing task:  2
# Accuracy:  0.92
# Testing task:  3
# Accuracy:  0.6845
# Testing task:  4
# Accuracy:  0.954
# [0.749, 0.301, 0.505, 0.3885, 0.68725, 0.9545, 0.5, 0.3905, 0.59125, 0.835, 0.6865, 0.479, 0.696, 0.92, 0.6845, 0.954]
# new ordering of classes:  ['truck', 'airplane', 'bird', 'deer', 'automobile', 'horse', 'cat', 'dog', 'ship', 'frog']
# Training task:  1
# Epoch:  0
# Accuracy:  0.59845
# Epoch:  1
# Accuracy:  0.6336
# Epoch:  2
# Accuracy:  0.66645
# Epoch:  3
# Accuracy:  0.68895
# Epoch:  4
# Accuracy:  0.74695
# Epoch:  5
# Accuracy:  0.7638
# Epoch:  6
# Accuracy:  0.82595
# Testing task:  1
# Accuracy:  0.7755
# Testing task:  2
# Accuracy:  0.4955
# Testing task:  3
# Accuracy:  0.507
# Testing task:  4
# Accuracy:  0.3745
# Training task:  2
# Epoch:  0
# Accuracy:  0.8197
# Testing task:  1
# Accuracy:  0.554
# Testing task:  2
# Accuracy:  0.8105
# Testing task:  3
# Accuracy:  0.4885
# Testing task:  4
# Accuracy:  0.291
# Training task:  3
# Epoch:  0
# Accuracy:  0.5
# Epoch:  1
# Accuracy:  0.501
# Epoch:  2
# Accuracy:  0.5083
# Epoch:  3
# Accuracy:  0.5862
# Epoch:  4
# Accuracy:  0.6279
# Epoch:  5
# Accuracy:  0.6953
# Epoch:  6
# Accuracy:  0.7101
# Epoch:  7
# Accuracy:  0.7155
# Epoch:  8
# Accuracy:  0.743
# Epoch:  9
# Accuracy:  0.7361
# Testing task:  1
# Accuracy:  0.58675
# Testing task:  2
# Accuracy:  0.8795
# Testing task:  3
# Accuracy:  0.6655
# Testing task:  4
# Accuracy:  0.3995
# Training task:  4
# Epoch:  0
# Accuracy:  0.9084
# Testing task:  1
# Accuracy:  0.543
# Testing task:  2
# Accuracy:  0.861
# Testing task:  3
# Accuracy:  0.609
# Testing task:  4
# Accuracy:  0.9005
# [0.7755, 0.4955, 0.507, 0.3745, 0.554, 0.8105, 0.4885, 0.291, 0.58675, 0.8795, 0.6655, 0.3995, 0.543, 0.861, 0.609, 0.9005]
# new ordering of classes:  ['truck', 'airplane', 'bird', 'deer', 'automobile', 'horse', 'cat', 'dog', 'ship', 'frog']
# Training task:  1
# Epoch:  0
# Accuracy:  0.56255
# Epoch:  1
# Accuracy:  0.60415
# Epoch:  2
# Accuracy:  0.5936
# Epoch:  3
# Accuracy:  0.61615
# Epoch:  4
# Accuracy:  0.6627
# Epoch:  5
# Accuracy:  0.765
# Epoch:  6
# Accuracy:  0.45385
# Epoch:  7
# Accuracy:  0.7606
# Epoch:  8
# Accuracy:  0.80915
# Testing task:  1
# Accuracy:  0.768
# Testing task:  2
# Accuracy:  0.5
# Testing task:  3
# Accuracy:  0.52
# Testing task:  4
# Accuracy:  0.5075
# Training task:  2
# Epoch:  0
# Accuracy:  0.9614
# Testing task:  1
# Accuracy:  0.702
# Testing task:  2
# Accuracy:  0.956
# Testing task:  3
# Accuracy:  0.536
# Testing task:  4
# Accuracy:  0.524
# Training task:  3
# Epoch:  0
# Accuracy:  0.6278
# Epoch:  1
# Accuracy:  0.6725
# Epoch:  2
# Accuracy:  0.6908
# Epoch:  3
# Accuracy:  0.7316
# Epoch:  4
# Accuracy:  0.7629
# Epoch:  5
# Accuracy:  0.7314
# Epoch:  6
# Accuracy:  0.7822
# Epoch:  7
# Accuracy:  0.7101
# Epoch:  8
# Accuracy:  0.7653
# Epoch:  9
# Accuracy:  0.8429
# Testing task:  1
# Accuracy:  0.4455
# Testing task:  2
# Accuracy:  0.77
# Testing task:  3
# Accuracy:  0.6985
# Testing task:  4
# Accuracy:  0.494
# Training task:  4
# Epoch:  0
# Accuracy:  0.9586
# Testing task:  1
# Accuracy:  0.38825
# Testing task:  2
# Accuracy:  0.8575
# Testing task:  3
# Accuracy:  0.5865
# Testing task:  4
# Accuracy:  0.96
# [0.768, 0.5, 0.52, 0.5075, 0.702, 0.956, 0.536, 0.524, 0.4455, 0.77, 0.6985, 0.494, 0.38825, 0.8575, 0.5865, 0.96]
# Run 9
# new ordering of classes:  ['ship', 'horse', 'deer', 'bird', 'frog', 'dog', 'airplane', 'automobile', 'truck', 'cat']
# Training task:  1
# Epoch:  0
# Accuracy:  0.59245
# Epoch:  1
# Accuracy:  0.63865
# Epoch:  2
# Accuracy:  0.69125
# Epoch:  3
# Accuracy:  0.6823
# Epoch:  4
# Accuracy:  0.7594
# Epoch:  5
# Accuracy:  0.73035
# Epoch:  6
# Accuracy:  0.7914
# Epoch:  7
# Accuracy:  0.7735
# Epoch:  8
# Accuracy:  0.82455
# Testing task:  1
# Accuracy:  0.748
# Testing task:  2
# Accuracy:  0.493
# Testing task:  3
# Accuracy:  0.5005
# Testing task:  4
# Accuracy:  0.5005
# Training task:  2
# Epoch:  0
# Accuracy:  0.8349
# Testing task:  1
# Accuracy:  0.55175
# Testing task:  2
# Accuracy:  0.848
# Testing task:  3
# Accuracy:  0.488
# Testing task:  4
# Accuracy:  0.501
# Training task:  3
# Epoch:  0
# Accuracy:  0.653
# Epoch:  1
# Accuracy:  0.8457
# Testing task:  1
# Accuracy:  0.6465
# Testing task:  2
# Accuracy:  0.794
# Testing task:  3
# Accuracy:  0.8545
# Testing task:  4
# Accuracy:  0.5
# Training task:  4
# Epoch:  0
# Accuracy:  0.8844
# Testing task:  1
# Accuracy:  0.6835
# Testing task:  2
# Accuracy:  0.818
# Testing task:  3
# Accuracy:  0.8765
# Testing task:  4
# Accuracy:  0.8705
# [0.748, 0.493, 0.5005, 0.5005, 0.55175, 0.848, 0.488, 0.501, 0.6465, 0.794, 0.8545, 0.5, 0.6835, 0.818, 0.8765, 0.8705]
# new ordering of classes:  ['ship', 'horse', 'deer', 'bird', 'frog', 'dog', 'airplane', 'automobile', 'truck', 'cat']
# Training task:  1
# Epoch:  0
# Accuracy:  0.494
# Epoch:  1
# Accuracy:  0.6227
# Epoch:  2
# Accuracy:  0.6739
# Epoch:  3
# Accuracy:  0.7048
# Epoch:  4
# Accuracy:  0.736
# Epoch:  5
# Accuracy:  0.71495
# Epoch:  6
# Accuracy:  0.79625
# Epoch:  7
# Accuracy:  0.83015
# Testing task:  1
# Accuracy:  0.7545
# Testing task:  2
# Accuracy:  0.5
# Testing task:  3
# Accuracy:  0.5675
# Testing task:  4
# Accuracy:  0.5335
# Training task:  2
# Epoch:  0
# Accuracy:  0.783
# Epoch:  1
# Accuracy:  0.8623
# Testing task:  1
# Accuracy:  0.64725
# Testing task:  2
# Accuracy:  0.8575
# Testing task:  3
# Accuracy:  0.576
# Testing task:  4
# Accuracy:  0.513
# Training task:  3
# Epoch:  0
# Accuracy:  0.8473
# Testing task:  1
# Accuracy:  0.64025
# Testing task:  2
# Accuracy:  0.8345
# Testing task:  3
# Accuracy:  0.857
# Testing task:  4
# Accuracy:  0.468
# Training task:  4
# Epoch:  0
# Accuracy:  0.9026
# Testing task:  1
# Accuracy:  0.6285
# Testing task:  2
# Accuracy:  0.8265
# Testing task:  3
# Accuracy:  0.83
# Testing task:  4
# Accuracy:  0.8935
# [0.7545, 0.5, 0.5675, 0.5335, 0.64725, 0.8575, 0.576, 0.513, 0.64025, 0.8345, 0.857, 0.468, 0.6285, 0.8265, 0.83, 0.8935]
# new ordering of classes:  ['ship', 'horse', 'deer', 'bird', 'frog', 'dog', 'airplane', 'automobile', 'truck', 'cat']
# Training task:  1
# Epoch:  0
# Accuracy:  0.582
# Epoch:  1
# Accuracy:  0.6204
# Epoch:  2
# Accuracy:  0.6806
# Epoch:  3
# Accuracy:  0.69015
# Epoch:  4
# Accuracy:  0.7327
# Epoch:  5
# Accuracy:  0.7799
# Epoch:  6
# Accuracy:  0.77335
# Epoch:  7
# Accuracy:  0.83435
# Testing task:  1
# Accuracy:  0.7355
# Testing task:  2
# Accuracy:  0.496
# Testing task:  3
# Accuracy:  0.5965
# Testing task:  4
# Accuracy:  0.4995
# Training task:  2
# Epoch:  0
# Accuracy:  0.6045
# Epoch:  1
# Accuracy:  0.7565
# Epoch:  2
# Accuracy:  0.8295
# Testing task:  1
# Accuracy:  0.57925
# Testing task:  2
# Accuracy:  0.8315
# Testing task:  3
# Accuracy:  0.65
# Testing task:  4
# Accuracy:  0.506
# Training task:  3
# Epoch:  0
# Accuracy:  0.7619
# Epoch:  1
# Accuracy:  0.8914
# Testing task:  1
# Accuracy:  0.55825
# Testing task:  2
# Accuracy:  0.827
# Testing task:  3
# Accuracy:  0.883
# Testing task:  4
# Accuracy:  0.4865
# Training task:  4
# Epoch:  0
# Accuracy:  0.8853
# Testing task:  1
# Accuracy:  0.57125
# Testing task:  2
# Accuracy:  0.814
# Testing task:  3
# Accuracy:  0.8635
# Testing task:  4
# Accuracy:  0.8785
# [0.7355, 0.496, 0.5965, 0.4995, 0.57925, 0.8315, 0.65, 0.506, 0.55825, 0.827, 0.883, 0.4865, 0.57125, 0.814, 0.8635, 0.8785]
# new ordering of classes:  ['ship', 'horse', 'deer', 'bird', 'frog', 'dog', 'airplane', 'automobile', 'truck', 'cat']
# Training task:  1
# Epoch:  0
# Accuracy:  0.57345
# Epoch:  1
# Accuracy:  0.60545
# Epoch:  2
# Accuracy:  0.6829
# Epoch:  3
# Accuracy:  0.7165
# Epoch:  4
# Accuracy:  0.6792
# Epoch:  5
# Accuracy:  0.77705
# Epoch:  6
# Accuracy:  0.8089
# Testing task:  1
# Accuracy:  0.75075
# Testing task:  2
# Accuracy:  0.4685
# Testing task:  3
# Accuracy:  0.499
# Testing task:  4
# Accuracy:  0.281
# Training task:  2
# Epoch:  0
# Accuracy:  0.7956
# Epoch:  1
# Accuracy:  0.8741
# Testing task:  1
# Accuracy:  0.587
# Testing task:  2
# Accuracy:  0.874
# Testing task:  3
# Accuracy:  0.5005
# Testing task:  4
# Accuracy:  0.366
# Training task:  3
# Epoch:  0
# Accuracy:  0.821
# Testing task:  1
# Accuracy:  0.38825
# Testing task:  2
# Accuracy:  0.6775
# Testing task:  3
# Accuracy:  0.825
# Testing task:  4
# Accuracy:  0.595
# Training task:  4
# Epoch:  0
# Accuracy:  0.9029
# Testing task:  1
# Accuracy:  0.18875
# Testing task:  2
# Accuracy:  0.627
# Testing task:  3
# Accuracy:  0.672
# Testing task:  4
# Accuracy:  0.8875
# [0.75075, 0.4685, 0.499, 0.281, 0.587, 0.874, 0.5005, 0.366, 0.38825, 0.6775, 0.825, 0.595, 0.18875, 0.627, 0.672, 0.8875]
# Run 10
# new ordering of classes:  ['ship', 'cat', 'frog', 'deer', 'truck', 'airplane', 'dog', 'automobile', 'horse', 'bird']
# Training task:  1
# Epoch:  0
# Accuracy:  0.50075
# Epoch:  1
# Accuracy:  0.61745
# Epoch:  2
# Accuracy:  0.6947
# Epoch:  3
# Accuracy:  0.71485
# Epoch:  4
# Accuracy:  0.7352
# Epoch:  5
# Accuracy:  0.7867
# Epoch:  6
# Accuracy:  0.80925
# Testing task:  1
# Accuracy:  0.7595
# Testing task:  2
# Accuracy:  0.4535
# Testing task:  3
# Accuracy:  0.4005
# Testing task:  4
# Accuracy:  0.5005
# Training task:  2
# Epoch:  0
# Accuracy:  0.5017
# Epoch:  1
# Accuracy:  0.7532
# Epoch:  2
# Accuracy:  0.9019
# Testing task:  1
# Accuracy:  0.68275
# Testing task:  2
# Accuracy:  0.8835
# Testing task:  3
# Accuracy:  0.4885
# Testing task:  4
# Accuracy:  0.478
# Training task:  3
# Epoch:  0
# Accuracy:  0.9308
# Testing task:  1
# Accuracy:  0.70825
# Testing task:  2
# Accuracy:  0.877
# Testing task:  3
# Accuracy:  0.9275
# Testing task:  4
# Accuracy:  0.483
# Training task:  4
# Epoch:  0
# Accuracy:  0.7673
# Epoch:  1
# Accuracy:  0.8193
# Testing task:  1
# Accuracy:  0.652
# Testing task:  2
# Accuracy:  0.8225
# Testing task:  3
# Accuracy:  0.9035
# Testing task:  4
# Accuracy:  0.819
# [0.7595, 0.4535, 0.4005, 0.5005, 0.68275, 0.8835, 0.4885, 0.478, 0.70825, 0.877, 0.9275, 0.483, 0.652, 0.8225, 0.9035, 0.819]
# new ordering of classes:  ['ship', 'cat', 'frog', 'deer', 'truck', 'airplane', 'dog', 'automobile', 'horse', 'bird']
# Training task:  1
# Epoch:  0
# Accuracy:  0.54235
# Epoch:  1
# Accuracy:  0.68155
# Epoch:  2
# Accuracy:  0.6969
# Epoch:  3
# Accuracy:  0.74045
# Epoch:  4
# Accuracy:  0.761
# Epoch:  5
# Accuracy:  0.78765
# Epoch:  6
# Accuracy:  0.7752
# Epoch:  7
# Accuracy:  0.8234
# Testing task:  1
# Accuracy:  0.75875
# Testing task:  2
# Accuracy:  0.5055
# Testing task:  3
# Accuracy:  0.5
# Testing task:  4
# Accuracy:  0.4525
# Training task:  2
# Epoch:  0
# Accuracy:  0.7986
# Epoch:  1
# Accuracy:  0.8924
# Testing task:  1
# Accuracy:  0.69875
# Testing task:  2
# Accuracy:  0.8755
# Testing task:  3
# Accuracy:  0.5
# Testing task:  4
# Accuracy:  0.5005
# Training task:  3
# Epoch:  0
# Accuracy:  0.9107
# Testing task:  1
# Accuracy:  0.52475
# Testing task:  2
# Accuracy:  0.6105
# Testing task:  3
# Accuracy:  0.924
# Testing task:  4
# Accuracy:  0.5515
# Training task:  4
# Epoch:  0
# Accuracy:  0.6628
# Epoch:  1
# Accuracy:  0.7482
# Epoch:  2
# Accuracy:  0.803
# Testing task:  1
# Accuracy:  0.6365
# Testing task:  2
# Accuracy:  0.863
# Testing task:  3
# Accuracy:  0.933
# Testing task:  4
# Accuracy:  0.787
# [0.75875, 0.5055, 0.5, 0.4525, 0.69875, 0.8755, 0.5, 0.5005, 0.52475, 0.6105, 0.924, 0.5515, 0.6365, 0.863, 0.933, 0.787]
# new ordering of classes:  ['ship', 'cat', 'frog', 'deer', 'truck', 'airplane', 'dog', 'automobile', 'horse', 'bird']
# Training task:  1
# Epoch:  0
# Accuracy:  0.59255
# Epoch:  1
# Accuracy:  0.62335
# Epoch:  2
# Accuracy:  0.7161
# Epoch:  3
# Accuracy:  0.70465
# Epoch:  4
# Accuracy:  0.71395
# Epoch:  5
# Accuracy:  0.7782
# Epoch:  6
# Accuracy:  0.81495
# Testing task:  1
# Accuracy:  0.7845
# Testing task:  2
# Accuracy:  0.3975
# Testing task:  3
# Accuracy:  0.5
# Testing task:  4
# Accuracy:  0.467
# Training task:  2
# Epoch:  0
# Accuracy:  0.6018
# Epoch:  1
# Accuracy:  0.8555
# Testing task:  1
# Accuracy:  0.69175
# Testing task:  2
# Accuracy:  0.857
# Testing task:  3
# Accuracy:  0.5
# Testing task:  4
# Accuracy:  0.383
# Training task:  3
# Epoch:  0
# Accuracy:  0.9291
# Testing task:  1
# Accuracy:  0.65375
# Testing task:  2
# Accuracy:  0.831
# Testing task:  3
# Accuracy:  0.924
# ...
# Epoch:  1
# Accuracy:  0.72405
# Epoch:  2
# Accuracy:  0.7275
# Epoch:  3
# Accuracy:  0.82205
# Testing task:  1
# Accuracy:  0.7965
# Testing task:  2
# Accuracy:  0.5025
# Testing task:  3
# Accuracy:  0.4
# Testing task:  4
# Accuracy:  0.5
# Training task:  2
# Epoch:  0
# Accuracy:  0.6948
# Epoch:  1
# Accuracy:  0.8054
# Testing task:  1
# Accuracy:  0.699
# Testing task:  2
# Accuracy:  0.7825
# Testing task:  3
# Accuracy:  0.4005
# Testing task:  4
# Accuracy:  0.5
# Training task:  3
# Epoch:  0
# Accuracy:  0.9489
# Testing task:  1
# Accuracy:  0.7065
# Testing task:  2
# Accuracy:  0.778
# Testing task:  3
# Accuracy:  0.9495
# Testing task:  4
# Accuracy:  0.5
# Training task:  4
# Epoch:  0
# Accuracy:  0.9139
# Testing task:  1
# Accuracy:  0.72175
# Testing task:  2
# Accuracy:  0.783
# Testing task:  3
# Accuracy:  0.9445
# Testing task:  4
# Accuracy:  0.9105
# [0.7965, 0.5025, 0.4, 0.5, 0.699, 0.7825, 0.4005, 0.5, 0.7065, 0.778, 0.9495, 0.5, 0.72175, 0.783, 0.9445, 0.9105]
# new ordering of classes:  ['automobile', 'cat', 'deer', 'airplane', 'dog', 'horse', 'ship', 'frog', 'truck', 'bird']
# Training task:  1
# Epoch:  0
# Accuracy:  0.6545
# Epoch:  1
# Accuracy:  0.76605
# Epoch:  2
# Accuracy:  0.7809
# Epoch:  3
# Accuracy:  0.8247
# Testing task:  1
# Accuracy:  0.797
# Testing task:  2
# Accuracy:  0.4845
# Testing task:  3
# Accuracy:  0.3915
# Testing task:  4
# Accuracy:  0.4865
# Training task:  2
# Epoch:  0
# Accuracy:  0.7053
# Epoch:  1
# Accuracy:  0.8231
# Testing task:  1
# Accuracy:  0.6875
# Testing task:  2
# Accuracy:  0.8075
# Testing task:  3
# Accuracy:  0.43
# Testing task:  4
# Accuracy:  0.511
# Training task:  3
# Epoch:  0
# Accuracy:  0.9511
# Testing task:  1
# Accuracy:  0.693
# Testing task:  2
# Accuracy:  0.7935
# Testing task:  3
# Accuracy:  0.958
# Testing task:  4
# Accuracy:  0.5
# Training task:  4
# Epoch:  0
# Accuracy:  0.9248
# Testing task:  1
# Accuracy:  0.6065
# Testing task:  2
# Accuracy:  0.7415
# Testing task:  3
# Accuracy:  0.877
# Testing task:  4
# Accuracy:  0.9225
# [0.797, 0.4845, 0.3915, 0.4865, 0.6875, 0.8075, 0.43, 0.511, 0.693, 0.7935, 0.958, 0.5, 0.6065, 0.7415, 0.877, 0.9225]
# Run 98
# new ordering of classes:  ['automobile', 'dog', 'airplane', 'ship', 'truck', 'bird', 'frog', 'deer', 'horse', 'cat']
# Training task:  1
# Epoch:  0
# Accuracy:  0.65365
# Epoch:  1
# Accuracy:  0.7262
# Epoch:  2
# Accuracy:  0.7899
# Epoch:  3
# Accuracy:  0.78955
# Epoch:  4
# Accuracy:  0.85255
# Testing task:  1
# Accuracy:  0.8115
# Testing task:  2
# Accuracy:  0.575
# Testing task:  3
# Accuracy:  0.5045
# Testing task:  4
# Accuracy:  0.5
# Training task:  2
# Epoch:  0
# Accuracy:  0.9333
# Testing task:  1
# Accuracy:  0.7895
# Testing task:  2
# Accuracy:  0.936
# Testing task:  3
# Accuracy:  0.501
# Testing task:  4
# Accuracy:  0.5
# Training task:  3
# Epoch:  0
# Accuracy:  0.684
# Epoch:  1
# Accuracy:  0.7469
# Epoch:  2
# Accuracy:  0.6512
# Epoch:  3
# Accuracy:  0.527
# Epoch:  4
# Accuracy:  0.8098
# Testing task:  1
# Accuracy:  0.7405
# Testing task:  2
# Accuracy:  0.8925
# Testing task:  3
# Accuracy:  0.795
# Testing task:  4
# Accuracy:  0.5
# Training task:  4
# Epoch:  0
# Accuracy:  0.6578
# Epoch:  1
# Accuracy:  0.756
# Epoch:  2
# Accuracy:  0.7443
# Epoch:  3
# Accuracy:  0.8094
# Testing task:  1
# Accuracy:  0.7265
# Testing task:  2
# Accuracy:  0.893
# Testing task:  3
# Accuracy:  0.778
# Testing task:  4
# Accuracy:  0.804
# [0.8115, 0.575, 0.5045, 0.5, 0.7895, 0.936, 0.501, 0.5, 0.7405, 0.8925, 0.795, 0.5, 0.7265, 0.893, 0.778, 0.804]
# new ordering of classes:  ['automobile', 'dog', 'airplane', 'ship', 'truck', 'bird', 'frog', 'deer', 'horse', 'cat']
# Training task:  1
# Epoch:  0
# Accuracy:  0.5545
# Epoch:  1
# Accuracy:  0.759
# Epoch:  2
# Accuracy:  0.77965
# Epoch:  3
# Accuracy:  0.7842
# Epoch:  4
# Accuracy:  0.83365
# Testing task:  1
# Accuracy:  0.8035
# Testing task:  2
# Accuracy:  0.351
# Testing task:  3
# Accuracy:  0.493
# Testing task:  4
# Accuracy:  0.4185
# Training task:  2
# Epoch:  0
# Accuracy:  0.935
# Testing task:  1
# Accuracy:  0.776
# Testing task:  2
# Accuracy:  0.936
# Testing task:  3
# Accuracy:  0.5415
# Testing task:  4
# Accuracy:  0.381
# Training task:  3
# Epoch:  0
# Accuracy:  0.7629
# Epoch:  1
# Accuracy:  0.7882
# Epoch:  2
# Accuracy:  0.8193
# Testing task:  1
# Accuracy:  0.7515
# Testing task:  2
# Accuracy:  0.879
# Testing task:  3
# Accuracy:  0.798
# Testing task:  4
# Accuracy:  0.512
# Training task:  4
# Epoch:  0
# Accuracy:  0.7316
# Epoch:  1
# Accuracy:  0.8059
# Testing task:  1
# Accuracy:  0.6965
# Testing task:  2
# Accuracy:  0.824
# Testing task:  3
# Accuracy:  0.783
# Testing task:  4
# Accuracy:  0.794
# [0.8035, 0.351, 0.493, 0.4185, 0.776, 0.936, 0.5415, 0.381, 0.7515, 0.879, 0.798, 0.512, 0.6965, 0.824, 0.783, 0.794]
# new ordering of classes:  ['automobile', 'dog', 'airplane', 'ship', 'truck', 'bird', 'frog', 'deer', 'horse', 'cat']
# Training task:  1
# Epoch:  0
# Accuracy:  0.5835
# Epoch:  1
# Accuracy:  0.6935
# Epoch:  2
# Accuracy:  0.8018
# Testing task:  1
# Accuracy:  0.77875
# Testing task:  2
# Accuracy:  0.5
# Testing task:  3
# Accuracy:  0.4465
# Testing task:  4
# Accuracy:  0.5
# Training task:  2
# Epoch:  0
# Accuracy:  0.7612
# Epoch:  1
# Accuracy:  0.8826
# Testing task:  1
# Accuracy:  0.63775
# Testing task:  2
# Accuracy:  0.8825
# Testing task:  3
# Accuracy:  0.4465
# Testing task:  4
# Accuracy:  0.5
# Training task:  3
# Epoch:  0
# Accuracy:  0.6196
# Epoch:  1
# Accuracy:  0.6817
# Epoch:  2
# Accuracy:  0.7862
# Epoch:  3
# Accuracy:  0.8042
# Testing task:  1
# Accuracy:  0.6915
# Testing task:  2
# Accuracy:  0.882
# Testing task:  3
# Accuracy:  0.7795
# Testing task:  4
# Accuracy:  0.5
# Training task:  4
# Epoch:  0
# Accuracy:  0.6996
# Epoch:  1
# Accuracy:  0.8121
# Testing task:  1
# Accuracy:  0.63625
# Testing task:  2
# Accuracy:  0.871
# Testing task:  3
# Accuracy:  0.7685
# Testing task:  4
# Accuracy:  0.7775
# [0.77875, 0.5, 0.4465, 0.5, 0.63775, 0.8825, 0.4465, 0.5, 0.6915, 0.882, 0.7795, 0.5, 0.63625, 0.871, 0.7685, 0.7775]
# new ordering of classes:  ['automobile', 'dog', 'airplane', 'ship', 'truck', 'bird', 'frog', 'deer', 'horse', 'cat']
# Training task:  1
# Epoch:  0
# Accuracy:  0.57115
# Epoch:  1
# Accuracy:  0.68715
# Epoch:  2
# Accuracy:  0.775
# Epoch:  3
# Accuracy:  0.78905
# Epoch:  4
# Accuracy:  0.8472
# Testing task:  1
# Accuracy:  0.82
# Testing task:  2
# Accuracy:  0.5035
# Testing task:  3
# Accuracy:  0.5
# Testing task:  4
# Accuracy:  0.535
# Training task:  2
# Epoch:  0
# Accuracy:  0.9317
# Testing task:  1
# Accuracy:  0.73375
# Testing task:  2
# Accuracy:  0.9365
# Testing task:  3
# Accuracy:  0.559
# Testing task:  4
# Accuracy:  0.5185
# Training task:  3
# Epoch:  0
# Accuracy:  0.7129
# Epoch:  1
# Accuracy:  0.7769
# Epoch:  2
# Accuracy:  0.8218
# Testing task:  1
# Accuracy:  0.56475
# Testing task:  2
# Accuracy:  0.678
# Testing task:  3
# Accuracy:  0.7935
# Testing task:  4
# Accuracy:  0.4765
# Training task:  4
# Epoch:  0
# Accuracy:  0.8187
# Testing task:  1
# Accuracy:  0.4295
# Testing task:  2
# Accuracy:  0.535
# Testing task:  3
# Accuracy:  0.774
# Testing task:  4
# Accuracy:  0.7985
# [0.82, 0.5035, 0.5, 0.535, 0.73375, 0.9365, 0.559, 0.5185, 0.56475, 0.678, 0.7935, 0.4765, 0.4295, 0.535, 0.774, 0.7985]
# Run 99
# new ordering of classes:  ['automobile', 'deer', 'airplane', 'ship', 'frog', 'horse', 'dog', 'bird', 'cat', 'truck']
# Training task:  1
# Epoch:  0
# Accuracy:  0.62985
# Epoch:  1
# Accuracy:  0.71745
# Epoch:  2
# Accuracy:  0.7811
# Epoch:  3
# Accuracy:  0.80955
# Testing task:  1
# Accuracy:  0.78675
# Testing task:  2
# Accuracy:  0.4825
# Testing task:  3
# Accuracy:  0.493
# Testing task:  4
# Accuracy:  0.5
# Training task:  2
# Epoch:  0
# Accuracy:  0.8279
# Testing task:  1
# Accuracy:  0.73825
# Testing task:  2
# Accuracy:  0.833
# Testing task:  3
# Accuracy:  0.5435
# Testing task:  4
# Accuracy:  0.5
# Training task:  3
# Epoch:  0
# Accuracy:  0.7011
# Epoch:  1
# Accuracy:  0.6112
# Epoch:  2
# Accuracy:  0.692
# Epoch:  3
# Accuracy:  0.7829
# Epoch:  4
# Accuracy:  0.7998
# Epoch:  5
# Accuracy:  0.801
# Testing task:  1
# Accuracy:  0.65225
# Testing task:  2
# Accuracy:  0.847
# Testing task:  3
# Accuracy:  0.771
# Testing task:  4
# Accuracy:  0.5
# Training task:  4
# Epoch:  0
# Accuracy:  0.9074
# Testing task:  1
# Accuracy:  0.72325
# Testing task:  2
# Accuracy:  0.8385
# Testing task:  3
# Accuracy:  0.8095
# Testing task:  4
# Accuracy:  0.9
# [0.78675, 0.4825, 0.493, 0.5, 0.73825, 0.833, 0.5435, 0.5, 0.65225, 0.847, 0.771, 0.5, 0.72325, 0.8385, 0.8095, 0.9]
# new ordering of classes:  ['automobile', 'deer', 'airplane', 'ship', 'frog', 'horse', 'dog', 'bird', 'cat', 'truck']
# Training task:  1
# Epoch:  0
# Accuracy:  0.63905
# Epoch:  1
# Accuracy:  0.73465
# Epoch:  2
# Accuracy:  0.77905
# Epoch:  3
# Accuracy:  0.80245
# Testing task:  1
# Accuracy:  0.77875
# Testing task:  2
# Accuracy:  0.4735
# Testing task:  3
# Accuracy:  0.4905
# Testing task:  4
# Accuracy:  0.303
# Training task:  2
# Epoch:  0
# Accuracy:  0.8408
# Testing task:  1
# Accuracy:  0.6745
# Testing task:  2
# Accuracy:  0.833
# Testing task:  3
# Accuracy:  0.619
# Testing task:  4
# Accuracy:  0.382
# Training task:  3
# Epoch:  0
# Accuracy:  0.7443
# Epoch:  1
# Accuracy:  0.8103
# Testing task:  1
# Accuracy:  0.6575
# Testing task:  2
# Accuracy:  0.842
# Testing task:  3
# Accuracy:  0.786
# Testing task:  4
# Accuracy:  0.437
# Training task:  4
# Epoch:  0
# Accuracy:  0.9292
# Testing task:  1
# Accuracy:  0.70925
# Testing task:  2
# Accuracy:  0.792
# Testing task:  3
# Accuracy:  0.746
# Testing task:  4
# Accuracy:  0.916
# [0.77875, 0.4735, 0.4905, 0.303, 0.6745, 0.833, 0.619, 0.382, 0.6575, 0.842, 0.786, 0.437, 0.70925, 0.792, 0.746, 0.916]
# new ordering of classes:  ['automobile', 'deer', 'airplane', 'ship', 'frog', 'horse', 'dog', 'bird', 'cat', 'truck']
# Training task:  1
# Epoch:  0
# Accuracy:  0.64335
# Epoch:  1
# Accuracy:  0.728
# Epoch:  2
# Accuracy:  0.72505
# Epoch:  3
# Accuracy:  0.78965
# Epoch:  4
# Accuracy:  0.7976
# Epoch:  5
# Accuracy:  0.85385
# Testing task:  1
# Accuracy:  0.80375
# Testing task:  2
# Accuracy:  0.5035
# Testing task:  3
# Accuracy:  0.5045
# Testing task:  4
# Accuracy:  0.5205
# Training task:  2
# Epoch:  0
# Accuracy:  0.6351
# Epoch:  1
# Accuracy:  0.7796
# Epoch:  2
# Accuracy:  0.8858
# Testing task:  1
# Accuracy:  0.69375
# Testing task:  2
# Accuracy:  0.886
# Testing task:  3
# Accuracy:  0.482
# Testing task:  4
# Accuracy:  0.489
# Training task:  3
# Epoch:  0
# Accuracy:  0.7423
# Epoch:  1
# Accuracy:  0.7826
# Epoch:  2
# Accuracy:  0.8174
# Testing task:  1
# Accuracy:  0.6635
# Testing task:  2
# Accuracy:  0.887
# Testing task:  3
# Accuracy:  0.7835
# Testing task:  4
# Accuracy:  0.529
# Training task:  4
# Epoch:  0
# Accuracy:  0.9322
# Testing task:  1
# Accuracy:  0.67475
# Testing task:  2
# Accuracy:  0.8785
# Testing task:  3
# Accuracy:  0.773
# Testing task:  4
# Accuracy:  0.909
# [0.80375, 0.5035, 0.5045, 0.5205, 0.69375, 0.886, 0.482, 0.489, 0.6635, 0.887, 0.7835, 0.529, 0.67475, 0.8785, 0.773, 0.909]
# new ordering of classes:  ['automobile', 'deer', 'airplane', 'ship', 'frog', 'horse', 'dog', 'bird', 'cat', 'truck']
# Training task:  1
# Epoch:  0
# Accuracy:  0.64115
# Epoch:  1
# Accuracy:  0.7317
# Epoch:  2
# Accuracy:  0.76855
# Epoch:  3
# Accuracy:  0.8123
# Testing task:  1
# Accuracy:  0.788
# Testing task:  2
# Accuracy:  0.5005
# Testing task:  3
# Accuracy:  0.539
# Testing task:  4
# Accuracy:  0.197
# Training task:  2
# Epoch:  0
# Accuracy:  0.8635
# Testing task:  1
# Accuracy:  0.5995
# Testing task:  2
# Accuracy:  0.873
# Testing task:  3
# Accuracy:  0.518
# Testing task:  4
# Accuracy:  0.366
# Training task:  3
# Epoch:  0
# Accuracy:  0.7379
# Epoch:  1
# Accuracy:  0.7749
# Epoch:  2
# Accuracy:  0.7836
# Epoch:  3
# Accuracy:  0.8115
# Testing task:  1
# Accuracy:  0.4815
# Testing task:  2
# Accuracy:  0.753
# Testing task:  3
# Accuracy:  0.788
# Testing task:  4
# Accuracy:  0.382
# Training task:  4
# Epoch:  0
# Accuracy:  0.9123
# Testing task:  1
# Accuracy:  0.5515
# Testing task:  2
# Accuracy:  0.7925
# Testing task:  3
# Accuracy:  0.6655
# Testing task:  4
# Accuracy:  0.911
# [0.788, 0.5005, 0.539, 0.197, 0.5995, 0.873, 0.518, 0.366, 0.4815, 0.753, 0.788, 0.382, 0.5515, 0.7925, 0.6655, 0.911]
# Run 100
# new ordering of classes:  ['automobile', 'airplane', 'bird', 'horse', 'cat', 'ship', 'deer', 'dog', 'frog', 'truck']
# Training task:  1
# Epoch:  0
# Accuracy:  0.6528
# Epoch:  1
# Accuracy:  0.7609
# Epoch:  2
# Accuracy:  0.8066
# Testing task:  1
# Accuracy:  0.79325
# Testing task:  2
# Accuracy:  0.548
# Testing task:  3
# Accuracy:  0.445
# Testing task:  4
# Accuracy:  0.5505
# Training task:  2
# Epoch:  0
# Accuracy:  0.9381
# Testing task:  1
# Accuracy:  0.7805
# Testing task:  2
# Accuracy:  0.9285
# Testing task:  3
# Accuracy:  0.415
# Testing task:  4
# Accuracy:  0.539
# Training task:  3
# Epoch:  0
# Accuracy:  0.73
# Epoch:  1
# Accuracy:  0.7698
# Epoch:  2
# Accuracy:  0.743
# Epoch:  3
# Accuracy:  0.8119
# Testing task:  1
# Accuracy:  0.665
# Testing task:  2
# Accuracy:  0.8865
# Testing task:  3
# Accuracy:  0.798
# Testing task:  4
# Accuracy:  0.5085
# Training task:  4
# Epoch:  0
# Accuracy:  0.9003
# Testing task:  1
# Accuracy:  0.7135
# Testing task:  2
# Accuracy:  0.916
# Testing task:  3
# Accuracy:  0.7865
# Testing task:  4
# Accuracy:  0.903
# [0.79325, 0.548, 0.445, 0.5505, 0.7805, 0.9285, 0.415, 0.539, 0.665, 0.8865, 0.798, 0.5085, 0.7135, 0.916, 0.7865, 0.903]
# new ordering of classes:  ['automobile', 'airplane', 'bird', 'horse', 'cat', 'ship', 'deer', 'dog', 'frog', 'truck']
# Training task:  1
# Epoch:  0
# Accuracy:  0.69575
# Epoch:  1
# Accuracy:  0.7468
# Epoch:  2
# Accuracy:  0.78375
# Epoch:  3
# Accuracy:  0.83995
# Testing task:  1
# Accuracy:  0.81675
# Testing task:  2
# Accuracy:  0.2345
# Testing task:  3
# Accuracy:  0.5
# Testing task:  4
# Accuracy:  0.516
# Training task:  2
# Epoch:  0
# Accuracy:  0.9432
# Testing task:  1
# Accuracy:  0.7865
# Testing task:  2
# Accuracy:  0.9275
# Testing task:  3
# Accuracy:  0.5
# Testing task:  4
# Accuracy:  0.527
# Training task:  3
# Epoch:  0
# Accuracy:  0.6715
# Epoch:  1
# Accuracy:  0.7868
# Epoch:  2
# Accuracy:  0.8247
# Testing task:  1
# Accuracy:  0.6455
# Testing task:  2
# Accuracy:  0.8775
# Testing task:  3
# Accuracy:  0.8175
# Testing task:  4
# Accuracy:  0.524
# Training task:  4
# Epoch:  0
# Accuracy:  0.913
# Testing task:  1
# Accuracy:  0.719
# Testing task:  2
# Accuracy:  0.9045
# Testing task:  3
# Accuracy:  0.7915
# Testing task:  4
# Accuracy:  0.912
# [0.81675, 0.2345, 0.5, 0.516, 0.7865, 0.9275, 0.5, 0.527, 0.6455, 0.8775, 0.8175, 0.524, 0.719, 0.9045, 0.7915, 0.912]
# new ordering of classes:  ['automobile', 'airplane', 'bird', 'horse', 'cat', 'ship', 'deer', 'dog', 'frog', 'truck']
# Training task:  1
# Epoch:  0
# Accuracy:  0.65645
# Epoch:  1
# Accuracy:  0.76045
# Epoch:  2
# Accuracy:  0.72325
# Epoch:  3
# Accuracy:  0.8051
# Testing task:  1
# Accuracy:  0.794
# Testing task:  2
# Accuracy:  0.369
# Testing task:  3
# Accuracy:  0.5355
# Testing task:  4
# Accuracy:  0.51
# Training task:  2
# Epoch:  0
# Accuracy:  0.8304
# Testing task:  1
# Accuracy:  0.575
# Testing task:  2
# Accuracy:  0.823
# Testing task:  3
# Accuracy:  0.5315
# Testing task:  4
# Accuracy:  0.6325
# Training task:  3
# Epoch:  0
# Accuracy:  0.6521
# Epoch:  1
# Accuracy:  0.7271
# Epoch:  2
# Accuracy:  0.7649
# Epoch:  3
# Accuracy:  0.7877
# Epoch:  4
# Accuracy:  0.7831
# Epoch:  5
# Accuracy:  0.8275
# Testing task:  1
# Accuracy:  0.65675
# Testing task:  2
# Accuracy:  0.904
# Testing task:  3
# Accuracy:  0.7995
# Testing task:  4
# Accuracy:  0.605
# Training task:  4
# Epoch:  0
# Accuracy:  0.9213
# Testing task:  1
# Accuracy:  0.666
# Testing task:  2
# Accuracy:  0.9135
# Testing task:  3
# Accuracy:  0.812
# Testing task:  4
# Accuracy:  0.9235
# [0.794, 0.369, 0.5355, 0.51, 0.575, 0.823, 0.5315, 0.6325, 0.65675, 0.904, 0.7995, 0.605, 0.666, 0.9135, 0.812, 0.9235]
# new ordering of classes:  ['automobile', 'airplane', 'bird', 'horse', 'cat', 'ship', 'deer', 'dog', 'frog', 'truck']
# Training task:  1
# Epoch:  0
# Accuracy:  0.61795
# Epoch:  1
# Accuracy:  0.71945
# Epoch:  2
# Accuracy:  0.7906
# Epoch:  3
# Accuracy:  0.80955
# Testing task:  1
# Accuracy:  0.7955
# Testing task:  2
# Accuracy:  0.4605
# Testing task:  3
# Accuracy:  0.4885
# Testing task:  4
# Accuracy:  0.5045
# Training task:  2
# Epoch:  0
# Accuracy:  0.9453
# Testing task:  1
# Accuracy:  0.762
# Testing task:  2
# Accuracy:  0.936
# Testing task:  3
# Accuracy:  0.4915
# Testing task:  4
# Accuracy:  0.504
# Training task:  3
# Epoch:  0
# Accuracy:  0.7637
# Epoch:  1
# Accuracy:  0.7697
# Epoch:  2
# Accuracy:  0.7278
# Epoch:  3
# Accuracy:  0.8165
# Testing task:  1
# Accuracy:  0.50875
# Testing task:  2
# Accuracy:  0.8405
# Testing task:  3
# Accuracy:  0.7905
# Testing task:  4
# Accuracy:  0.481
# Training task:  4
# Epoch:  0
# Accuracy:  0.9285
# Testing task:  1
# Accuracy:  0.65425
# Testing task:  2
# Accuracy:  0.8985
# Testing task:  3
# Accuracy:  0.543
# Testing task:  4
# Accuracy:  0.929
# [0.7955, 0.4605, 0.4885, 0.5045, 0.762, 0.936, 0.4915, 0.504, 0.50875, 0.8405, 0.7905, 0.481, 0.65425, 0.8985, 0.543, 0.929]

# %%
plot_task_accuracies(average_AGEM_accuracies, N_TASKS)
plot_task_accuracies(average_GEM_accuracies, N_TASKS)
plot_task_accuracies(average_REPLAY_accuracies, N_TASKS)
plot_task_accuracies(average_NAIVE_accuracies, N_TASKS)
